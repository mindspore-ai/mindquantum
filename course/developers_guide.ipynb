# %% [markdown]
# - [MindQuantum开发指南](#mindquantum开发指导)
#   - [准备MindQuantum代码仓](#准备mindquantun代码仓)
#     - [第一步：登录Gitee官网](#第一步登录gitee官网)
#     - [第二步：Fork MindQuantum主仓库到个人空间](#第二步fork-mindQuantum主仓库到个人空间)
#     - [第三步：复制MindQuantum个人代码仓地址](#第三步复制mindquantum个人代码仓地址)
#     - [第四步：欢迎Watch、Star和Fork MindSpore的主仓到个人空间（可选）](#第四步欢迎watch、star和fork-mindspore的主仓到个人空间（可选）)
#   - [登录HiQ量子计算云服务](#登录hiq量子计算云服务)
#   - [开发量子线路](#开发量子线路)
#     - [第一步：新建Jupyter Notebook实例](#第一步新建jupyter-notebook实例)
#     - [第二步：导入MindQuantum代码仓](#第二步导入mindquantum代码仓)
#     - [第三步：安装mindquantum-master包](#第三步安装mindquantum-master包)
#     - [第四步：开发量子线路](#第四步开发量子线路)
#   - [提交代码到代码仓](#提交代码到代码仓)
#     - [第一步：提交代码到个人仓库](#第五步提交代码到个人仓库)
#     - [第二步：提交代码到主仓库](#第六步提交代码到主仓库)
#
# ## 准备MindQuantum代码仓
#
# 更多样例代码请访问[MindQuantum开源教程](https://gitee.com/mindspore/mindquantum/tree/master/tutorials)，在体验样例前需要先准备MindQuantum代码仓，具体操作步骤如下：
#
# ### 第一步：登录Gitee官网
#
# 访问[Gitee官网](https://gitee.com/login)并登录，如未注册Gitee账号，需要先注册账号。
#
# ### 第二步：Fork MindQuantum主仓库到个人空间
#
# 访问[MindQuantum主仓库](https://gitee.com/mindspore/mindquantum)，点击右上角【Fork】按钮，欢迎Watch和Star MindQuantum代码仓。
#
# ![](https://hiq.huaweicloud.com/document/media/example1/fork.png)
#
# 如果之前已经Fork过代码仓，先同步个人代码仓到最新版本，点击右上角【个人主页】。
#
# ![](https://hiq.huaweicloud.com/document/media/example1/fork_home.png)
#
# 找到已经Fork的 MindQuantum代码仓，点击进入个人MindQuantum代码仓页面。
#
# ![](https://hiq.huaweicloud.com/document/media/example1/fork_mindquantum.png)
#
# 点击【刷新】按钮，拉取最新的MindQuantum代码。
#
# ![](https://hiq.huaweicloud.com/document/media/example1/refresh.png)
#
# ### 第三步：复制MindQuantum个人代码仓地址
#
# 点击【克隆/下载】按钮，再点击【复制】按钮。
#
# ![](https://hiq.huaweicloud.com/document/media/example1/clone.png)
#
# ### 第四步：欢迎Watch、Star和Fork MindSpore的主仓到个人空间（可选）
#
# https://gitee.com/mindspore/mindspore
#
# ![](https://hiq.huaweicloud.com/document/media/example1/mindspore.png)
#
# ## 登录HiQ量子计算云服务
#
# 点击[HiQ量子计算云服务](https://hiq.huaweicloud.com/portal/home)登录入口（华为云账号登录，若没有华为云账号，请先注册华为云账号并实名认证）。
#
# ![](https://hiq.huaweicloud.com/document/media/CloudPlatrorm/overview.png)

# %% [markdown]
# ## 开发量子线路
#
# ### 第一步：新建Jupyter Notebook实例
#
# 点击新建实例，填写实例名称及描述，点击【确定】按钮，进入Jupyter Notebook界面。
#
# ![](https://hiq.huaweicloud.com/document/media/example3/instance.png)
#
# ### 第二步：导入MindQuantum代码仓
#
# 进入Jupyter Notebook界面后，选择Other区域中Terminal模块，打开命令行终端。
#
# ![](https://hiq.huaweicloud.com/document/media/example3/terminal.png)
#
# 输入以下命令：

# %% [markdown]
# ```sh
# pwd          #查看当前目录
# ls           #查看目录文件
# ```
#
# ![](https://hiq.huaweicloud.com/document/media/example2/command1.png)
#
# ```sh
# cd work     #进入工作目录
# ```
#
# ![](https://hiq.huaweicloud.com/document/media/example2/command2.png)
#
# ```sh
# git clone "个人代码仓地址"
# ```
#
# （例如：git clone https://gitee.com/git_username/mindquantum.git，个人代码仓地址获取详见《准备MindQuantum代码仓》第三步：复制MindQuantum个人代码仓地址，git_username是gitee账号名称，在Terminal界面输入以上命令，导入时需要输入Gitee的账号和密码。）
#
# ![](https://hiq.huaweicloud.com/document/media/example2/command3.png)
#
# ### 第三步：安装mindquantum-master包
#
# 输入以下安装命令（点击查看最新版[PiP安装包及操作指导](https://www.mindspore.cn/mindquantum/docs/zh-CN/master/mindquantum_install.html)）。

# %%
pip install https://hiq.huaweicloud.com/download/mindquantum/newest/linux/mindquantum-master-cp37-cp37m-linux_x86_64.whl -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting mindquantum==master
#   Downloading https://hiq.huaweicloud.com/download/mindquantum/newest/linux/mindquantum-master-cp37-cp37m-linux_x86_64.whl (818 kB)
#      |████████████████████████████████| 818 kB 59.6 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from mindquantum==master) (1.21.4)
# Requirement already satisfied: sympy>=1.4 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from mindquantum==master) (1.9)
# Requirement already satisfied: importlib-metadata>=0.9 in /home/ma-user/modelarts/modelarts-sdk (from mindquantum==master) (4.12.0)
# Requirement already satisfied: scipy>=1.5.3 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from mindquantum==master) (1.7.2)
# Requirement already satisfied: openfermion>=1.0.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from mindquantum==master) (1.2.0)
# Collecting matplotlib<=3.4.3
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/7c/ec/3d77b10ac3d30590f5431fd2dc59c58d20c020af107b47f8974896afc5c9/matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 4.3 MB/s eta 0:00:01
# Requirement already satisfied: projectq>=0.5.1 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from mindquantum==master) (0.6.1)
# Requirement already satisfied: rich>=10.9.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from mindquantum==master) (12.0.1)
# Requirement already satisfied: zipp>=0.5 in /home/ma-user/modelarts/modelarts-sdk (from importlib-metadata>=0.9->mindquantum==master) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ma-user/modelarts/modelarts-sdk (from importlib-metadata>=0.9->mindquantum==master) (4.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ma-user/modelarts/common-algo-toolkit (from matplotlib<=3.4.3->mindquantum==master) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from matplotlib<=3.4.3->mindquantum==master) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ma-user/modelarts/common-algo-toolkit (from matplotlib<=3.4.3->mindquantum==master) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from matplotlib<=3.4.3->mindquantum==master) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/ma-user/modelarts/common-algo-toolkit (from matplotlib<=3.4.3->mindquantum==master) (0.11.0)
# Requirement already satisfied: cirq-core~=0.12.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from openfermion>=1.0.0->mindquantum==master) (0.12.0)
# Requirement already satisfied: h5py>=2.8 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from openfermion>=1.0.0->mindquantum==master) (2.10.0)
# Requirement already satisfied: cirq-google~=0.12.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from openfermion>=1.0.0->mindquantum==master) (0.12.0)
# Requirement already satisfied: pubchempy in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from openfermion>=1.0.0->mindquantum==master) (1.0.4)
# Requirement already satisfied: networkx in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from openfermion>=1.0.0->mindquantum==master) (2.6.3)
# Requirement already satisfied: deprecation in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from openfermion>=1.0.0->mindquantum==master) (2.1.0)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.7/site-packages (from openfermion>=1.0.0->mindquantum==master) (5.1.3)
# Requirement already satisfied: requests~=2.18 in /home/ma-user/modelarts/modelarts-sdk (from openfermion>=1.0.0->mindquantum==master) (2.27.1)
# Requirement already satisfied: sortedcontainers~=2.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from cirq-core~=0.12.0->openfermion>=1.0.0->mindquantum==master) (2.4.0)
# Requirement already satisfied: pandas in /home/ma-user/modelarts/modelarts-sdk (from cirq-core~=0.12.0->openfermion>=1.0.0->mindquantum==master) (1.3.5)
# Requirement already satisfied: tqdm in /home/ma-user/modelarts/modelarts-sdk (from cirq-core~=0.12.0->openfermion>=1.0.0->mindquantum==master) (4.62.3)
# Requirement already satisfied: protobuf~=3.13.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from cirq-google~=0.12.0->openfermion>=1.0.0->mindquantum==master) (3.13.0)
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.14.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from cirq-google~=0.12.0->openfermion>=1.0.0->mindquantum==master) (1.31.4)
# Requirement already satisfied: packaging>=14.3 in /home/ma-user/modelarts/common-algo-toolkit (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google~=0.12.0->openfermion>=1.0.0->mindquantum==master) (21.0)
# Requirement already satisfied: six>=1.13.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google~=0.12.0->openfermion>=1.0.0->mindquantum==master) (1.16.0)
# Requirement already satisfied: pytz in /home/ma-user/modelarts/modelarts-sdk (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google~=0.12.0->openfermion>=1.0.0->mindquantum==master) (2022.1)
# Requirement already satisfied: google-auth<2.0dev,>=1.25.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google~=0.12.0->openfermion>=1.0.0->mindquantum==master) (1.35.0)
# Requirement already satisfied: setuptools>=40.3.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google~=0.12.0->openfermion>=1.0.0->mindquantum==master) (58.0.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google~=0.12.0->openfermion>=1.0.0->mindquantum==master) (1.53.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.29.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google~=0.12.0->openfermion>=1.0.0->mindquantum==master) (1.42.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google~=0.12.0->openfermion>=1.0.0->mindquantum==master) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google~=0.12.0->openfermion>=1.0.0->mindquantum==master) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google~=0.12.0->openfermion>=1.0.0->mindquantum==master) (4.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google~=0.12.0->openfermion>=1.0.0->mindquantum==master) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ma-user/modelarts/modelarts-sdk (from requests~=2.18->openfermion>=1.0.0->mindquantum==master) (1.26.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from requests~=2.18->openfermion>=1.0.0->mindquantum==master) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ma-user/modelarts/modelarts-sdk (from requests~=2.18->openfermion>=1.0.0->mindquantum==master) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ma-user/modelarts/modelarts-sdk (from requests~=2.18->openfermion>=1.0.0->mindquantum==master) (2.0.12)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from rich>=10.9.0->mindquantum==master) (2.10.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from rich>=10.9.0->mindquantum==master) (0.9.1)
# Requirement already satisfied: mpmath>=0.19 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from sympy>=1.4->mindquantum==master) (1.2.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbformat->openfermion>=1.0.0->mindquantum==master) (4.2.1)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.7/site-packages (from nbformat->openfermion>=1.0.0->mindquantum==master) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from nbformat->openfermion>=1.0.0->mindquantum==master) (5.1.1)
# Requirement already satisfied: jupyter-core in /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages (from nbformat->openfermion>=1.0.0->mindquantum==master) (4.9.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->openfermion>=1.0.0->mindquantum==master) (5.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->openfermion>=1.0.0->mindquantum==master) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->openfermion>=1.0.0->mindquantum==master) (0.18.0)
# Installing collected packages: matplotlib, mindquantum
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.1
#     Uninstalling matplotlib-3.5.1:
#       Successfully uninstalled matplotlib-3.5.1
#   Attempting uninstall: mindquantum
#     Found existing installation: mindquantum 0.5.0rc1
#     Uninstalling mindquantum-0.5.0rc1:
#       Successfully uninstalled mindquantum-0.5.0rc1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ma-cau 1.1.3 requires matplotlib==3.5.1, but you have matplotlib 3.4.3 which is incompatible.
# ma-cau 1.1.3 requires pandas==1.3.4, but you have pandas 1.3.5 which is incompatible.
# ma-cau 1.1.3 requires Pillow==9.0.1, but you have pillow 8.4.0 which is incompatible.
# ma-cau 1.1.3 requires tenacity<=6.1.0, but you have tenacity 8.0.1 which is incompatible.
# ma-cau 1.1.3 requires typing-extensions<=4.0.1, but you have typing-extensions 4.1.1 which is incompatible.
# Successfully installed matplotlib-3.4.3 mindquantum-0.7.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 检查mindquantum-master包是否安装成功，显示版本号为安装版本号（现在最新为0.7），则说明安装成功。

# %%
pip show mindquantum
# Out:
# Name: mindquantum
# Version: 0.7.0
# Summary: A hybrid quantum-classic framework for quantum computing
# Home-page: https://www.mindspore.cn/
# Author: The MindSpore Authors
# Author-email: contact@mindspore.cn
# License: Apache License Version 2.0
# Location: /home/ma-user/anaconda3/envs/MindQuantum/lib/python3.7/site-packages
# Requires: rich, numpy, sympy, matplotlib, scipy, openfermion, projectq, importlib-metadata
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 第四步：开发量子线路
#
# **切换开发分支**
#
# 以代码在research分支开发为例说明：将代码从master分支切换到research分支，在Jupyter Notebook的Terminal里执行如下命令，
#
# ```sh
# cd mindquantum/
#
# cd pwd
# ```
#
# ![](https://hiq.huaweicloud.com/document/media/example2/commit_code1.png)
#
# ```sh
# git branch
# ```
#
# ![](https://hiq.huaweicloud.com/document/media/example2/commit_code2.png)
#
# ```sh
# git checkout research
# ```
#
# ![](https://hiq.huaweicloud.com/document/media/example2/commit_code3.png)
#
# ```sh
# git branch
# ```
#
# ![](https://hiq.huaweicloud.com/document/media/example2/commit_code4.png)
#
# **新建Notebook文件**
#
# 在左侧目录树创建或者选择存放代码的文件夹，选择Notebook区域中MindQuantum模块，并将文件模式切换成【code】。
#
# ![](https://hiq.huaweicloud.com/document/media/example3/newfile.png)
#
# ![](https://hiq.huaweicloud.com/document/media/example3/newfilecode.png)
#
# **导入数据包**
#
# 导入本教程所依赖的模块，点击【运行】按钮。
#
# (量子线路部分补充到这里)

# %% [markdown]
# ## 提交代码到代码仓
#
# ### 第一步：提交代码到个人仓库
#
# 代码开发完，提交到gitee mindquantum代码仓，请执行如下命令：
#
# ```sh
# git status  #查看要提交的更新文件
# ```
#
# ![](https://hiq.huaweicloud.com/document/media/example2/commit_code5.png)
#
# ```sh
# git add .    #提交代码
# ```
#
# ![](https://hiq.huaweicloud.com/document/media/example2/commit_code6.png)
#
# git status	#查看代码是否已经提交成功
#
# ![](https://hiq.huaweicloud.com/document/media/example2/commit_code7.png)
#
# ```sh
# git commit -m "commit message"	#commit message是提交说明信息
# ```
#
# ![](https://hiq.huaweicloud.com/document/media/example2/commit_code8.png)
#
# 在commit前需要配置gitee代码仓的用户名和邮箱，然后再执行commit命令。
#
# ```sh
# git config –-global user.name "Your Name"
# git config –-global user.email "you@example.com"
# git commit -m "commit message"
# ```
#
# ![](https://hiq.huaweicloud.com/document/media/example2/commit_code9.png)
#
# 输入将本地分支修改提交到远程分支，在push过程中需要输入gitee用户名和密码。
#
# ```sh
# git push
# ```
#
# ![](https://hiq.huaweicloud.com/document/media/example2/commit_code10.png)
#
# ### 第二步：提交代码到主仓库
#
# 注意：若开发者在样例教程上做了进一步开发，可通过pull request的方式将更新提交到mindquantum的主仓库，参与MindQuantum开源项目，步骤如下
#
# **(1) 创建PR提交代码到主仓库**
#
# 回到Gitee MindQuantum主仓库界面，点击【Pull Request】，将个人远程仓代码提交到mindquantum的主仓库，完成最终的代码提交。
#
# ![](https://hiq.huaweicloud.com/document/media/example1/pullrequest.png)
#
# 将源分支和目标分支选为mindspore/mindquantum的research分支。填写PR标题，取消勾选【合并后关闭提到的issue】。选择所需的审查人员后，即可创建PR。
#
# ![](https://hiq.huaweicloud.com/document/media/example1/research.png)
#
# (2) 签署CLA
#
# 首次参与MindQuantum开源的开发者，在评论区会发现没有签署CLA。请进入签署页面，选择【sign individual cla】，并根据gitee上的个人信息，填写签署信息，完成CLA的签署。回到PR页面，在评论区回复【/check-cla】，检查cla是否签署完成，如果没有，则需稍等片刻。签署完后，提交PR流程结束。
#
# ![](https://hiq.huaweicloud.com/document/media/example1/cla.png)
#
#
# 更多代码样例参见 https://gitee.com/mindspore/mindquantum/tree/master/tutorials
