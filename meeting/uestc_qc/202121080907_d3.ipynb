# %% [markdown]
# # Day 3
# $$
# |\psi_{2}\rangle=\frac{1}{\sqrt{2^n}}\sum\nolimits_{x}(-1)^{f(x)}|x\rangle\left[\frac{|0\rangle-|1\rangle}{\sqrt{2}}\right]
# $$
# 怎么证明上面的一系列 CNOT 能够实现平衡函数的某一情况下的oracle？

# %%
from mindquantum import Simulator, Circuit, X, H, BarrierGate, Measure
import numpy as np

n = 2

circ = Circuit()
circ += X.on(n)
circ += BarrierGate(show=False)
for i in range(n+1):
    circ += H.on(i)
for i in range(n):
    circ += X.on(n, i)
circ += BarrierGate(show=False)
for i in range(n):
    circ += H.on(i)
print("circuit:\n{}".format(circ))
print()

sim = Simulator('projectq', n+1)
sim.apply_circuit(circ)

for i in range(n+1):
    circ += Measure().on(i)


def measure(input):
    s0 = np.zeros(2**(n+1))
    s0[input] = 1
    sim.set_qs(s0)
    print("input: {}\n{}".format(sim.get_qs(True), sim.sampling(circ, shots=2000)))
    print()


for i in range(2**(n+1)):
    measure(i)
# Out:
# circuit:
# q0: ───────H────●─────────H──
#                 │
# q1: ───────H────┼────●────H──
#                 │    │
# q2: ──X────H────X────X───────
#
# input: 1¦000⟩
# shots: 2000
# Keys: q2 q1 q0│0.00   0.129       0.259       0.388       0.517       0.646
# ──────────────┼───────────┴───────────┴───────────┴───────────┴───────────┴
#            011│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#               │
#            111│▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓
#               │
# {'011': 966, '111': 1034}
#
# input: 1¦001⟩
# shots: 2000
# Keys: q2 q1 q0│0.00   0.131       0.262       0.393       0.524       0.656
# ──────────────┼───────────┴───────────┴───────────┴───────────┴───────────┴
#            010│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#               │
#            110│▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓
#               │
# {'010': 951, '110': 1049}
#
# input: 1¦010⟩
# shots: 2000
# Keys: q2 q1 q0│0.00   0.128       0.255       0.383        0.51       0.637
# ──────────────┼───────────┴───────────┴───────────┴───────────┴───────────┴
#            001│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#               │
#            101│▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓
#               │
# {'001': 980, '101': 1020}
#
# input: 1¦011⟩
# shots: 2000
# Keys: q2 q1 q0│0.00   0.127       0.255       0.382       0.509       0.636
# ──────────────┼───────────┴───────────┴───────────┴───────────┴───────────┴
#            000│▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓
#               │
#            100│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#               │
# {'000': 1018, '100': 982}
#
# input: 1¦100⟩
# shots: 2000
# Keys: q2 q1 q0│0.00   0.127       0.254       0.381       0.508       0.636
# ──────────────┼───────────┴───────────┴───────────┴───────────┴───────────┴
#            000│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#               │
#            100│▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓
#               │
# {'000': 983, '100': 1017}
#
# input: 1¦101⟩
# shots: 2000
# Keys: q2 q1 q0│0.00   0.127       0.254       0.381       0.507       0.634
# ──────────────┼───────────┴───────────┴───────────┴───────────┴───────────┴
#            001│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#               │
#            101│▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓
#               │
# {'001': 985, '101': 1015}
#
# input: 1¦110⟩
# shots: 2000
# Keys: q2 q1 q0│0.00   0.131       0.262       0.393       0.524       0.656
# ──────────────┼───────────┴───────────┴───────────┴───────────┴───────────┴
#            010│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#               │
#            110│▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓
#               │
# {'010': 951, '110': 1049}
#
# input: 1¦111⟩
# shots: 2000
# Keys: q2 q1 q0│0.00    0.13       0.259       0.389       0.518       0.648
# ──────────────┼───────────┴───────────┴───────────┴───────────┴───────────┴
#            011│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#               │
#            111│▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓
#               │
# {'011': 963, '111': 1037}
