# %% [markdown]
# # 利用MindQuantum解决组合优化问题

# %%
# !pip install networkx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://repo.huaweicloud.com/repository/pypi/simple
# Looking in links: https://obs-workspace-20180810.obs.cn-north-1.myhuaweicloud.com/pypi/index.html
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (2.6.2)
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import networkx as nx

# %%
g = nx.gnm_random_graph(9, 20, seed=42)
nx.draw(g,with_labels=True, font_weight='bold')

# %%
print(list(g.edges))
# Out:
# [(0, 1), (0, 8), (0, 2), (0, 4), (0, 3), (1, 8), (1, 6), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4), (3, 8), (3, 6), (3, 5), (4, 7), (4, 5), (4, 6), (5, 6), (7, 8)]

# %% [markdown]
# ## nx库中的解法

# %%
cut, partition = nx.algorithms.approximation.one_exchange(g)
print(cut, partition)
# Out:
# 14 ({8, 3, 4}, {0, 1, 2, 5, 6, 7})

# %% [markdown]
# ## Try to solve by yourself

# %%
def solution(edges):
    pass

# %%
my_cut = solution(list(g.edges))
print(f'I get {my_cut} cuts')
# Out:
# I get None cuts

# %% [markdown]
# ## QAOA

# %%
from mindquantum import *

# %%
depth = 1
ansatz = MaxCutAnsatz(list(g.edges), depth)

ham = ansatz.hamiltonian
circuit = ansatz.circuit
circuit
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# q0: ──H────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                │             │             │             │             │
# q1: ──H────ZZ(beta_0)────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                              │             │             │             │              │             │             │             │
# q2: ──H──────────────────────┼─────────ZZ(beta_0)────────┼─────────────┼──────────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                              │                           │             │              │             │             │             │              │             │
# q3: ──H──────────────────────┼───────────────────────────┼─────────ZZ(beta_0)─────────┼─────────────┼─────────ZZ(beta_0)────────┼──────────ZZ(beta_0)────────┼──────────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)─────────────────────────────────────────────────────────────
#                              │                           │                            │             │                           │                            │              │             │             │             │
# q4: ──H──────────────────────┼───────────────────────ZZ(beta_0)───────────────────────┼─────────────┼───────────────────────ZZ(beta_0)───────────────────ZZ(beta_0)─────ZZ(beta_0)────────┼─────────────┼─────────────┼──────────ZZ(beta_0)────ZZ(beta_0)─────ZZ(beta_0)────RX(alpha_0)─────────────────
#                              │                                                        │             │                                                                                     │             │             │              │             │              │
# q5: ──H──────────────────────┼────────────────────────────────────────────────────────┼─────────────┼─────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────ZZ(beta_0)─────────┼─────────ZZ(beta_0)─────────┼──────────ZZ(beta_0)────RX(alpha_0)──
#                              │                                                        │             │                                                                                     │             │                            │                            │              │
# q6: ──H──────────────────────┼────────────────────────────────────────────────────────┼─────────ZZ(beta_0)────────────────────────────────────────────────────────────────────────────────┼─────────ZZ(beta_0)───────────────────────┼────────────────────────ZZ(beta_0)─────ZZ(beta_0)────RX(alpha_0)──
#                              │                                                        │                                                                                                   │                                          │
# q7: ──H──────────────────────┼────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)────────────────────────────────
#                              │                                                        │                                                                                                   │                                                        │
# q8: ──H──────────────────ZZ(beta_0)───────────────────────────────────────────────ZZ(beta_0)──────────────────────────────────────────────────────────────────────────────────────────ZZ(beta_0)───────────────────────────────────────────────ZZ(beta_0)────RX(alpha_0)────────────────────────────────

# %%
depth = 3
ansatz = MaxCutAnsatz(list(g.edges), depth)

ham = ansatz.hamiltonian
circuit = ansatz.circuit
sim = Simulator('projectq', circuit.n_qubits)
grad_ops = sim.get_expectation_with_grad(Hamiltonian(-ham), circuit)
grad_ops(np.random.random(size=len(circuit.params_name)))
np.random.seed(1)
x0 = np.random.random(len(circuit.params_name))
opti = optimizers[2]
tol = 1e-4
res = minimize(fun, x0, method=opti, jac=True, tol=tol)
# Out:
# Cut value: 7.359574310741286
# Cut value: 8.851406021401965
# Cut value: 10.54669022797708
# Cut value: 9.920566388589535
# Cut value: 10.54669022797708
# Cut value: 9.997158874970722
# Cut value: 10.047673372699943
# Cut value: 9.498720328159084
# Cut value: 10.552002616814093
# Cut value: 10.457848725408633
# Cut value: 10.552002616814093
# Cut value: 6.583021415780673
# Cut value: 7.121777081814237
# Cut value: 10.552002616814093
# Cut value: 11.344516654600671
# Cut value: 10.054593213730122
# Cut value: 11.489122720874075
# Cut value: 11.488864494660472
# Cut value: 11.489176996764307
# Cut value: 11.467621819799685
# Cut value: 11.489024587998554
# Cut value: 11.489176996764307
# Cut value: 10.833835603196663
# Cut value: 10.409037814136536
# Cut value: 11.489176996764307
# Cut value: 11.246334328336838
# Cut value: 9.006939335044905
# Cut value: 12.009239657242535
# Cut value: 12.013457792716281
# Cut value: 12.071306692169376
# Cut value: 12.016482692821647
# Cut value: 12.073953974735518
# Cut value: 12.074104577090182
# Cut value: 12.074094424724134
# Cut value: 12.074104577090182
# Cut value: 8.542823183639427
# Cut value: 6.534717083793373
# Cut value: 12.074104577090182
# Cut value: 9.834802959797813
# Cut value: 11.500345335511165
# Cut value: 12.085385332802655
# Cut value: 12.08537096232866
# Cut value: 12.085386664986864
# Cut value: 12.085385526795779
# Cut value: 12.085386664986864
# Cut value: 11.965951573287567
# Cut value: 12.06055037145942
# Cut value: 12.085386664986864
# Cut value: 12.220369330207248
# Cut value: 12.129754824762042
# Cut value: 12.226353186098828
# Cut value: 12.22342423210919
# Cut value: 12.226949035392039
# Cut value: 12.226950394939111
# Cut value: 12.226909789914057
# Cut value: 12.226950394939111
# Cut value: 11.007364366843124
# Cut value: 9.667322429590653
# Cut value: 12.226950394939111
# Cut value: 10.67391094655813
# Cut value: 12.351382489450813
# Cut value: 12.404538791770216
# Cut value: 12.405563464262187
# Cut value: 12.405555003641528
# Cut value: 12.405535660792687
# Cut value: 9.524112738434969
# Cut value: 12.405563464262187
# Cut value: 9.08437529420117
# Cut value: 9.104762390665826
# Cut value: 12.405563464262187
# Cut value: 10.111717502979491
# Cut value: 9.679644263474781
# Cut value: 11.927762503546052
# Cut value: 11.921254684385527
# Cut value: 12.406644575268036
# Cut value: 12.407095210257392
# Cut value: 12.407116229224545
# Cut value: 12.407116091493943
# Cut value: 12.407116055098337
# Cut value: 12.407116229224545
# Cut value: 12.011633040011443
# Cut value: 10.32886479919145
# Cut value: 12.407116229224545
# Cut value: 10.260857810042786
# Cut value: 12.970932104103966
# Cut value: 12.905572019955466
# Cut value: 12.974371974939926
# Cut value: 12.974352931353106
# Cut value: 12.974277253821683
# Cut value: 12.974371974939926
# Cut value: 10.330748011184303
# Cut value: 10.875456677670183
# Cut value: 12.974371974939926
# Cut value: 11.628371540584734
# Cut value: 11.626841131895016
# Cut value: 12.95094594828841
# Cut value: 13.002537010793517
# Cut value: 13.005618197577686
# Cut value: 13.005633897414533
# Cut value: 13.005632191759915
# Cut value: 13.00562949181343
# Cut value: 13.005633897414533
# Cut value: 10.514788097721587
# Cut value: 8.59926691428495
# Cut value: 13.005633897414533
# Cut value: 10.78409637077591
# Cut value: 12.877151305740881
# Cut value: 13.105377894670312
# Cut value: 13.10544785062309
# Cut value: 13.10544026470857
# Cut value: 13.105435389240196
# Cut value: 13.10544785062309
# Cut value: 11.655613731141575
# Cut value: 11.76576756297305
# Cut value: 13.10544785062309
# Cut value: 12.16577486559627
# Cut value: 11.535261135351828
# Cut value: 12.846010893671297
# Cut value: 12.86284891818683
# Cut value: 13.102582707510853
# Cut value: 13.105829631446358
# Cut value: 13.1058534174193
# Cut value: 13.10585352143309
# Cut value: 13.10585348779832
# Cut value: 13.10585352143309
# Cut value: 10.11862988600218
# Cut value: 8.578674570713169
# Cut value: 13.10585352143309
# Cut value: 11.321124812537516
# Cut value: 12.65712843455141
# Cut value: 13.12084584596435
# Cut value: 13.12150442743136
# Cut value: 13.12150887092726
# Cut value: 13.12150734315307
# Cut value: 12.952941764505805
# Cut value: 13.12150887092726
# Cut value: 12.952941764505805
# Cut value: 11.34869667965275
# Cut value: 13.12150887092726
# Cut value: 12.807697418984203
# Cut value: 13.15228956027989
# Cut value: 13.154973241121365
# Cut value: 13.155024389424696
# Cut value: 13.15502134678312
# Cut value: 13.155020774439702
# Cut value: 13.155024389424696
# Cut value: 9.8502630731218
# Cut value: 8.248119807455637
# Cut value: 13.155024389424696
# Cut value: 9.976868408381524
# Cut value: 8.866972502374193
# Cut value: 12.427892828201303
# Cut value: 11.97603458605169
# Cut value: 13.145124686985305
# Cut value: 13.155968714696757
# Cut value: 13.156146910248776
# Cut value: 13.156147230685853
# Cut value: 13.15614708645302
# Cut value: 13.156147230685853
# Cut value: 9.524293802657596
# Cut value: 8.207851627775007
# Cut value: 13.156147230685853
# Cut value: 11.630458731160097
# Cut value: 12.3702070519115
# Cut value: 13.159988165379522
# Cut value: 13.160263255537316
# Cut value: 13.160265381203661
# Cut value: 13.160264971629287
# Cut value: 13.16026496696621
# Cut value: 13.160265381203661
# Cut value: 10.231013741998767
# Cut value: 10.34002524862309
# Cut value: 13.160265381203661
# Cut value: 11.188587149487272
# Cut value: 10.890149428154078
# Cut value: 12.992817564439552
# Cut value: 12.892391856767755
# Cut value: 13.176345054078595
# Cut value: 13.176904360246885
# Cut value: 13.176952831024883
# Cut value: 13.17695230292992
# Cut value: 13.17695009426783
# Cut value: 13.176952831024883
# Cut value: 10.02637213563326
# Cut value: 8.524346419863546
# Cut value: 13.176952831024883
# Cut value: 11.619870870292665
# Cut value: 12.601142051184066
# Cut value: 13.176989656608683
# Cut value: 13.176992020673946
# Cut value: 13.17699203351884
# Cut value: 13.1769920296179
# Cut value: 13.17699203351884
# Cut value: 11.552844675174835
# Cut value: 11.764162702839478
# Cut value: 13.17699203351884
# Cut value: 12.264709267302567
# Cut value: 11.39814289727951
# Cut value: 12.92222208422201
# Cut value: 12.852607289854522
# Cut value: 13.174158518847797
# Cut value: 13.178447340510266
# Cut value: 13.178471510706824
# Cut value: 13.1784718280549
# Cut value: 13.178471657545941
# Cut value: 13.1784718280549
# Cut value: 13.142014973896483
# Cut value: 13.062254332408685
# Cut value: 13.1784718280549
# Cut value: 13.158843235599564
# Cut value: 13.174924572801753
# Cut value: 13.178743542874965
# Cut value: 13.178743937718481
# Cut value: 13.178743945561362
# Cut value: 13.178743898773579
# Cut value: 13.109237813768118
# Cut value: 13.178743945561362
# Cut value: 9.852408213566807
# Cut value: 8.372659790999261
# Cut value: 13.178743945561362
# Cut value: 9.982786446025276
# Cut value: 8.819259135449538
# Cut value: 12.463303164051652
# Cut value: 11.876749262253657
# Cut value: 13.16922537317159
# Cut value: 13.182001619385364
# Cut value: 13.182095308157642
# Cut value: 13.182096298211114
# Cut value: 13.182095894031187
# Cut value: 13.182096298211114
# Cut value: 9.74967581374198
# Cut value: 8.45618131126816
# Cut value: 13.182096298211114
# Cut value: 11.683002963627121
# Cut value: 12.460652568305157
# Cut value: 13.183623565536045
# Cut value: 13.183938969159108
# Cut value: 13.183939487140446
# Cut value: 13.18393930220931
# Cut value: 13.183939487140446
# Cut value: 10.198289774938676
# Cut value: 10.349031706270889
# Cut value: 13.183939487140446
# Cut value: 11.18205223609127
# Cut value: 10.793105945924095
# Cut value: 12.911154789480708
# Cut value: 12.64468288919482
# Cut value: 13.183761764227285
# Cut value: 13.185792645945805
# Cut value: 13.18579241608407
# Cut value: 13.185792508302312
# Cut value: 13.185792645945805
# Cut value: 9.953880499214288
# Cut value: 8.461995332593883
# Cut value: 13.185792645945805
# Cut value: 11.615998914149557
# Cut value: 12.578602410216185
# Cut value: 13.18580881786536
# Cut value: 13.185809908930581
# Cut value: 13.18580993269567
# Cut value: 13.18580993097204
# Cut value: 13.185809930961305
# Cut value: 13.18580993269567
# Cut value: 11.62053430939594
# Cut value: 11.8624357107444
# Cut value: 13.18580993269567
# Cut value: 12.34459006247368
# Cut value: 11.606756969087934
# Cut value: 12.929945912017715
# Cut value: 12.923538028268329
# Cut value: 13.181581638103667
# Cut value: 13.185602335337407
# Cut value: 13.18581182266932
# Cut value: 13.18581187343191
# Cut value: 13.185811873334476
# Cut value: 13.185811873143344
# Cut value: 13.18581187343191
# Cut value: 13.136775830526034
# Cut value: 13.071767827327388
# Cut value: 13.18581187343191
# Cut value: 13.168843484968296
# Cut value: 13.178874555589243
# Cut value: 13.185810550645833
# Cut value: 13.185812109387033
# Cut value: 13.185812109452009
# Cut value: 13.185812109429104
# Cut value: 13.18628551750033
# Cut value: 13.185812109452009
# Cut value: 13.18628551750033
# Cut value: 13.172633730822024
# Cut value: 13.18628551750033
# Cut value: 13.183201209087763
# Cut value: 13.186894934820351
# Cut value: 13.186902068210728
# Cut value: 13.186902042222933
# Cut value: 13.186901873357893
# Cut value: 13.186902068210728
# Cut value: 13.13454990343273
# Cut value: 13.067973257399196
# Cut value: 13.186902068210728
# Cut value: 13.169161472375961
# Cut value: 13.179468874763256
# Cut value: 13.18690088522659
# Cut value: 13.186903015759416
# Cut value: 13.186903015778327
# Cut value: 13.18690301560823
# Cut value: 13.186903015778327
# Cut value: 9.937905195068499
# Cut value: 8.601454022581919
# Cut value: 13.186903015778327
# Cut value: 11.638025113698891
# Cut value: 12.552483307306993
# Cut value: 13.186485184297148
# Cut value: 13.186910647591597
# Cut value: 13.186910967614237
# Cut value: 13.186910966821202
# Cut value: 13.186910966816875
# Cut value: 13.186910967614237
# Cut value: 10.185562700529488
# Cut value: 10.37843773408242
# Cut value: 13.186910967614237
# Cut value: 11.189476905622989
# Cut value: 10.820614497461303
# Cut value: 12.871828369234539
# Cut value: 12.720322950208264
# Cut value: 13.18443093371102
# Cut value: 13.18692409658025
# Cut value: 13.186970400602576
# Cut value: 13.1869703945364
# Cut value: 13.186970394760046
# Cut value: 13.186970400602576
# Cut value: 9.968899205881476
# Cut value: 8.467710409258164
# Cut value: 13.186970400602576
# Cut value: 11.612200053965516
# Cut value: 12.583403074607764
# Cut value: 13.186973479347234
# Cut value: 13.186975434036945
# Cut value: 13.18697544739868
# Cut value: 13.186975446896364
# Cut value: 13.186975446891504
# Cut value: 13.18697544739868
# Cut value: 11.662796246059546
# Cut value: 11.910002195233558
# Cut value: 13.18697544739868
# Cut value: 12.384787894941827
# Cut value: 11.689049758056047
# Cut value: 12.936858066554201
# Cut value: 12.94014725172767
# Cut value: 13.182942280816837
# Cut value: 13.186970558191966
# Cut value: 13.186991404909879
# Cut value: 13.186991421505727
# Cut value: 13.18699142019597
# Cut value: 13.186991419609338
# Cut value: 13.186991421505727
# Cut value: 13.18607383055349
# Cut value: 13.183829055787776
# Cut value: 13.186991421505727
# Cut value: 13.186455831666336
# Cut value: 13.18690255425961
# Cut value: 13.186999493280506
# Cut value: 13.186999493314417
# Cut value: 13.186999491726187

# %%
sim = Simulator('projectq', circuit.n_qubits)
grad_ops = sim.get_expectation_with_grad(Hamiltonian(-ham), circuit)

# %%
import numpy as np

grad_ops(np.random.random(size=len(circuit.params_name)))
# Out:
# (array([[-9.95120808-1.93870098e-17j]]),
#  array([[[-1.52539797+0.j,  0.05130718+0.j]]]))

# %% [markdown]
# ### 利用`scipy`的优化器进行优化

# %%
from scipy.optimize import minimize

def fun(x):
    f, g = grad_ops(x)
    print(f"Cut value: {-f.real[0, 0]}")
    return f.real[0, 0], g.real[0, 0]

np.random.seed(1)
x0 = np.random.random(len(circuit.params_name))
optimizers = ['cg', 'COBYLA', 'Powell', 'bfgs']
opti = optimizers[0]
tol = 1e-1
res = minimize(fun, x0, method=opti, jac=True, tol=tol)
# Out:
# Cut value: 7.571326575273143
# Cut value: 8.798041290493822
# Cut value: 10.27051540332838
# Cut value: 10.853664731765745
# Cut value: 9.75098304244031
# Cut value: 10.240686172250285
# Cut value: 10.895373273967287
# Cut value: 10.958835300494751
# Cut value: 10.978826727914939
# Cut value: 10.077157328731733
# Cut value: 10.979958324452282

# %%
def get_partitions(theta, first_n=1):
    s = Simulator('projectq', circuit.n_qubits)
    s.apply_circuit(circuit, dict(zip(circuit.params_name, theta)))
    state = s.get_qs()
    amp = np.abs(state)**2
    partitions=[]
    for n in range(first_n):
        poi = np.argmax(amp)
        amp[poi] = -1
        bin_string = bin(poi)[2:].zfill(circuit.n_qubits)[::-1]
        partition = [[], []]
        for i, j in enumerate(bin_string):
            partition[int(j)].append(i)
        partitions.append(partition)
    return partitions

def get_cut_value(graph, partitions):
    values = []
    for partition in partitions:
        value = 0
        for p0 in partition[0]:
            for p1 in partition[1]:
                for g in graph:
                    if p0 in g and p1 in g:
                        value += 1
        values.append(value)
    return values

# %%
partitions = get_partitions(res.x, 6)
for i, j in enumerate(partitions):
    print(f'partition {i}: {j}')
# Out:
# partition 0: [[1, 2, 4, 5, 8], [0, 3, 6, 7]]
# partition 1: [[0, 3, 6, 7], [1, 2, 4, 5, 8]]
# partition 2: [[0, 1, 2, 5, 6, 7], [3, 4, 8]]
# partition 3: [[3, 4, 8], [0, 1, 2, 5, 6, 7]]
# partition 4: [[2, 4, 6, 8], [0, 1, 3, 5, 7]]
# partition 5: [[0, 1, 3, 5, 7], [2, 4, 6, 8]]

# %%
cut_values = get_cut_value(g.edges, partitions)
print(f'cut values: {cut_values}')
print(f'\nYour configuration:\ndepth: {depth}\nmethod: {opti}\ntol: {tol}\nstep: {res.nfev}')
# Out:
# cut values: [14, 14, 14, 14, 14, 14]
#
# Your configuration:
# depth: 3
# method: Powell
# tol: 0.0001
# step: 365
