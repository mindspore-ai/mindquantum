# %% [markdown]
# # 利用MindQuantum解决组合优化问题

# %%
# !pip install networkx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://repo.huaweicloud.com/repository/pypi/simple
# Looking in links: https://obs-workspace-20180810.obs.cn-north-1.myhuaweicloud.com/pypi/index.html
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (2.6.2)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import networkx as nx

# %%
g = nx.gnm_random_graph(9, 20, seed=42)
nx.draw(g,with_labels=True, font_weight='bold')

# %%
print(list(g.edges))
# Out:
# [(0, 1), (0, 8), (0, 2), (0, 4), (0, 3), (1, 8), (1, 6), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4), (3, 8), (3, 6), (3, 5), (4, 7), (4, 5), (4, 6), (5, 6), (7, 8)]

# %% [markdown]
# ## nx库中的解法

# %%
cut, partition = nx.algorithms.approximation.one_exchange(g)
print(cut, partition)
# Out:
# 14 ({8, 3, 4}, {0, 1, 2, 5, 6, 7})

# %% [markdown]
# ## Try to solve by yourself

# %%
def solution(edges):
    pass

# %%
my_cut = solution(list(g.edges))
print(f'I get {my_cut} cuts')
# Out:
# I get None cuts

# %% [markdown]
# ## QAOA

# %%
from mindquantum import *

# %%
depth = 3
ansatz = MaxCutAnsatz(list(g.edges), depth)

ham = ansatz.hamiltonian
circuit = ansatz.circuit
circuit
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# q0: ──H────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)─────────────────────────────────────────────────────────────ZZ(beta_1)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────ZZ(beta_1)────ZZ(beta_1)────ZZ(beta_1)────ZZ(beta_1)────RX(alpha_1)─────────────────────────────────────────────────────────────ZZ(beta_2)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────ZZ(beta_2)────ZZ(beta_2)────ZZ(beta_2)────ZZ(beta_2)────RX(alpha_2)────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                │             │             │             │             │                                                                                     │                                                                                                                                                │             │             │             │                                                                                     │                                                                                                                                                │             │             │             │
# q1: ──H────ZZ(beta_0)────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)────ZZ(beta_1)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_1)────ZZ(beta_1)────ZZ(beta_1)────ZZ(beta_1)────RX(alpha_1)────ZZ(beta_2)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_2)────ZZ(beta_2)────ZZ(beta_2)────ZZ(beta_2)────RX(alpha_2)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                              │             │             │             │              │             │             │             │                                                                                                                                                                             │             │             │             │              │             │             │             │                                                                                                                                                                             │             │             │             │              │             │             │             │
# q2: ──H──────────────────────┼─────────ZZ(beta_0)────────┼─────────────┼──────────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────ZZ(beta_1)────────┼─────────────┼──────────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_1)────ZZ(beta_1)────RX(alpha_1)────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────ZZ(beta_2)────────┼─────────────┼──────────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_2)────ZZ(beta_2)────RX(alpha_2)──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                              │                           │             │              │             │             │             │              │             │                                                                                                                                                │                           │             │              │             │             │             │              │             │                                                                                                                                                │                           │             │              │             │             │             │              │             │
# q3: ──H──────────────────────┼───────────────────────────┼─────────ZZ(beta_0)─────────┼─────────────┼─────────ZZ(beta_0)────────┼──────────ZZ(beta_0)────────┼──────────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)───────────────────────────────────────────────────────────────────┼───────────────────────────┼─────────ZZ(beta_1)─────────┼─────────────┼─────────ZZ(beta_1)────────┼──────────ZZ(beta_1)────────┼──────────ZZ(beta_1)────ZZ(beta_1)────ZZ(beta_1)────ZZ(beta_1)────RX(alpha_1)───────────────────────────────────────────────────────────────────┼───────────────────────────┼─────────ZZ(beta_2)─────────┼─────────────┼─────────ZZ(beta_2)────────┼──────────ZZ(beta_2)────────┼──────────ZZ(beta_2)────ZZ(beta_2)────ZZ(beta_2)────ZZ(beta_2)────RX(alpha_2)─────────────────────────────────────────────────────────────
#                              │                           │                            │             │                           │                            │              │             │             │             │                                                                                       │                           │                            │             │                           │                            │              │             │             │             │                                                                                       │                           │                            │             │                           │                            │              │             │             │             │
# q4: ──H──────────────────────┼───────────────────────ZZ(beta_0)───────────────────────┼─────────────┼───────────────────────ZZ(beta_0)───────────────────ZZ(beta_0)─────ZZ(beta_0)────────┼─────────────┼─────────────┼──────────ZZ(beta_0)────ZZ(beta_0)─────ZZ(beta_0)────RX(alpha_0)───────────────────────┼───────────────────────ZZ(beta_1)───────────────────────┼─────────────┼───────────────────────ZZ(beta_1)───────────────────ZZ(beta_1)─────ZZ(beta_1)────────┼─────────────┼─────────────┼──────────ZZ(beta_1)────ZZ(beta_1)─────ZZ(beta_1)────RX(alpha_1)───────────────────────┼───────────────────────ZZ(beta_2)───────────────────────┼─────────────┼───────────────────────ZZ(beta_2)───────────────────ZZ(beta_2)─────ZZ(beta_2)────────┼─────────────┼─────────────┼──────────ZZ(beta_2)────ZZ(beta_2)─────ZZ(beta_2)────RX(alpha_2)─────────────────
#                              │                                                        │             │                                                                                     │             │             │              │             │              │                                           │                                                        │             │                                                                                     │             │             │              │             │              │                                           │                                                        │             │                                                                                     │             │             │              │             │              │
# q5: ──H──────────────────────┼────────────────────────────────────────────────────────┼─────────────┼─────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────ZZ(beta_0)─────────┼─────────ZZ(beta_0)─────────┼──────────ZZ(beta_0)────RX(alpha_0)────────┼────────────────────────────────────────────────────────┼─────────────┼─────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────ZZ(beta_1)─────────┼─────────ZZ(beta_1)─────────┼──────────ZZ(beta_1)────RX(alpha_1)────────┼────────────────────────────────────────────────────────┼─────────────┼─────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────ZZ(beta_2)─────────┼─────────ZZ(beta_2)─────────┼──────────ZZ(beta_2)────RX(alpha_2)──
#                              │                                                        │             │                                                                                     │             │                            │                            │              │                            │                                                        │             │                                                                                     │             │                            │                            │              │                            │                                                        │             │                                                                                     │             │                            │                            │              │
# q6: ──H──────────────────────┼────────────────────────────────────────────────────────┼─────────ZZ(beta_0)────────────────────────────────────────────────────────────────────────────────┼─────────ZZ(beta_0)───────────────────────┼────────────────────────ZZ(beta_0)─────ZZ(beta_0)────RX(alpha_0)────────┼────────────────────────────────────────────────────────┼─────────ZZ(beta_1)────────────────────────────────────────────────────────────────────────────────┼─────────ZZ(beta_1)───────────────────────┼────────────────────────ZZ(beta_1)─────ZZ(beta_1)────RX(alpha_1)────────┼────────────────────────────────────────────────────────┼─────────ZZ(beta_2)────────────────────────────────────────────────────────────────────────────────┼─────────ZZ(beta_2)───────────────────────┼────────────────────────ZZ(beta_2)─────ZZ(beta_2)────RX(alpha_2)──
#                              │                                                        │                                                                                                   │                                          │                                                                        │                                                        │                                                                                                   │                                          │                                                                        │                                                        │                                                                                                   │                                          │
# q7: ──H──────────────────────┼────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)──────────────────────────────────────┼────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────ZZ(beta_1)────ZZ(beta_1)────RX(alpha_1)──────────────────────────────────────┼────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────ZZ(beta_2)────ZZ(beta_2)────RX(alpha_2)────────────────────────────────
#                              │                                                        │                                                                                                   │                                                        │                                                          │                                                        │                                                                                                   │                                                        │                                                          │                                                        │                                                                                                   │                                                        │
# q8: ──H──────────────────ZZ(beta_0)───────────────────────────────────────────────ZZ(beta_0)──────────────────────────────────────────────────────────────────────────────────────────ZZ(beta_0)───────────────────────────────────────────────ZZ(beta_0)────RX(alpha_0)──────────────────────────────────ZZ(beta_1)───────────────────────────────────────────────ZZ(beta_1)──────────────────────────────────────────────────────────────────────────────────────────ZZ(beta_1)───────────────────────────────────────────────ZZ(beta_1)────RX(alpha_1)──────────────────────────────────ZZ(beta_2)───────────────────────────────────────────────ZZ(beta_2)──────────────────────────────────────────────────────────────────────────────────────────ZZ(beta_2)───────────────────────────────────────────────ZZ(beta_2)────RX(alpha_2)────────────────────────────────

# %%
sim = Simulator('projectq', circuit.n_qubits)
grad_ops = sim.get_expectation_with_grad(Hamiltonian(-ham), circuit)

# %%
import numpy as np

grad_ops(np.random.random(size=len(circuit.params_name)))
# Out:
# (array([[-9.40307739-8.55488899e-17j]]),
#  array([[[-1.35339837+0.j,  1.10337184+0.j,  0.72511189+0.j,
#           -0.43161297+0.j,  3.99980871+0.j, -1.0112337 +0.j]]]))

# %% [markdown]
# ### 利用`scipy`的优化器进行优化

# %%
from scipy.optimize import minimize

def fun(x):
    f, g = grad_ops(x)
    print(f"Cut value: {-f.real[0, 0]}")
    return f.real[0, 0], g.real[0, 0]

np.random.seed(1)
x0 = np.random.random(len(circuit.params_name))
optimizers = ['cg', 'COBYLA', 'Powell', 'bfgs']
opti = optimizers[2]
tol = 1e-3
res = minimize(fun, x0, method=opti, jac=True, tol=tol)
# Out:
# Cut value: 7.359574310741286
# Cut value: 8.851406021401965
# Cut value: 10.54669022797708
# Cut value: 9.920566388589535
# Cut value: 10.54669022797708
# Cut value: 9.997158874970722
# Cut value: 10.047673372699943
# Cut value: 6.072303029706303
# Cut value: 10.293014891558897
# Cut value: 10.54669022797708
# Cut value: 7.141829911423407
# Cut value: 7.50720057763202
# Cut value: 10.54669022797708
# Cut value: 11.090463259919261
# Cut value: 9.943772265475408
# Cut value: 11.254278413547722
# Cut value: 11.246435790709995
# Cut value: 11.246759527351692
# Cut value: 11.254278413547722
# Cut value: 10.774696913808224
# Cut value: 10.419050623534044
# Cut value: 11.254278413547722
# Cut value: 11.221384738818386
# Cut value: 8.949192718883586
# Cut value: 12.008674279017283
# Cut value: 11.949833440068184
# Cut value: 12.075714723538042
# Cut value: 12.005291413450164
# Cut value: 12.08138458275438
# Cut value: 12.072760039547768
# Cut value: 12.08138458275438
# Cut value: 8.581887029664967
# Cut value: 6.471618503607907
# Cut value: 12.08138458275438
# Cut value: 9.694500276256441
# Cut value: 11.566379176859506
# Cut value: 12.104452559115696
# Cut value: 12.10436881662035
# Cut value: 12.104104181428866
# Cut value: 12.104452559115696
# Cut value: 11.991458157919384
# Cut value: 12.082383408411543
# Cut value: 12.104452559115696
# Cut value: 12.247806279553615
# Cut value: 12.156347605206378
# Cut value: 12.254748429358617
# Cut value: 12.244562645210834
# Cut value: 12.256057624600846
# Cut value: 10.96309923188097
# Cut value: 9.567114506036393
# Cut value: 12.256057624600846
# Cut value: 10.638183371726953
# Cut value: 12.377303829408838
# Cut value: 12.436313470042862
# Cut value: 12.436943968033304
# Cut value: 12.43389936545383
# Cut value: 9.43893336817602
# Cut value: 12.436943968033304
# Cut value: 9.234345558677504
# Cut value: 9.017323556490666
# Cut value: 12.436943968033304
# Cut value: 10.068158076371235
# Cut value: 9.691604790820447
# Cut value: 12.131610293519547
# Cut value: 11.777017368240148
# Cut value: 12.447811359459596
# Cut value: 12.447660200522474
# Cut value: 12.447738093969617
# Cut value: 12.447811359459596
# Cut value: 12.086146931067601
# Cut value: 10.335407212855996
# Cut value: 12.447811359459596
# Cut value: 10.253488361578079
# Cut value: 13.01649196807248
# Cut value: 12.967907770667793
# Cut value: 13.021412792192606
# Cut value: 13.015374657594721
# Cut value: 13.021412792192606
# Cut value: 10.3664649559774
# Cut value: 10.808846512834684
# Cut value: 13.021412792192606
# Cut value: 11.566298238054056
# Cut value: 11.496052011605489
# Cut value: 12.965677263100076
# Cut value: 13.025125456888265
# Cut value: 13.047284376846202
# Cut value: 13.033949986357804
# Cut value: 13.047220343655663
# Cut value: 13.046801439714741
# Cut value: 13.047284376846202
# Cut value: 10.588595844746193
# Cut value: 8.672640292738194
# Cut value: 13.047284376846202
# Cut value: 10.920685464083949
# Cut value: 12.88348714020422
# Cut value: 13.1260972066403
# Cut value: 13.125611243801664
# Cut value: 13.125063424745456
# Cut value: 13.1260972066403
# Cut value: 11.74411205925231
# Cut value: 11.849657841322248
# Cut value: 13.1260972066403
# Cut value: 12.264891984173468
# Cut value: 11.564920623950412
# Cut value: 12.915570227836332
# Cut value: 12.819584169870167
# Cut value: 13.126339825652781
# Cut value: 13.128973253615396
# Cut value: 13.128953793446057
# Cut value: 13.128934443049635
# Cut value: 13.128973253615396
# Cut value: 10.160304361830384
# Cut value: 8.6163683292154
# Cut value: 13.128973253615396
# Cut value: 11.339631098391303
# Cut value: 12.688893649331295
# Cut value: 13.145170508460634
# Cut value: 13.14583101419065
# Cut value: 13.14560063001301
# Cut value: 13.14571263319915
# Cut value: 12.822324740488087
# Cut value: 13.14583101419065
# Cut value: 12.822324740488087
# Cut value: 11.624881076608915
# Cut value: 13.14583101419065
# Cut value: 12.815697218031538
# Cut value: 13.152247568678696
# Cut value: 13.16820255981309
# Cut value: 13.16798665394678
# Cut value: 13.167971196537568
# Cut value: 13.16820255981309
# Cut value: 9.847463459429727
# Cut value: 8.313782114136806
# Cut value: 13.16820255981309
# Cut value: 9.975135025818444
# Cut value: 8.797792981213895
# Cut value: 12.383346221487901
# Cut value: 12.02586066506551
# Cut value: 13.154806258236448
# Cut value: 13.167645317040416
# Cut value: 13.168209355383276
# Cut value: 13.168209515093523
# Cut value: 13.168209442506452
# Cut value: 13.168209515093523
# Cut value: 9.651588749686827
# Cut value: 8.347922220179665
# Cut value: 13.168209515093523
# Cut value: 11.657327327435581
# Cut value: 12.419744609667351
# Cut value: 13.170595748250964
# Cut value: 13.170894551255655
# Cut value: 13.17087737290934
# Cut value: 13.170855868600004
# Cut value: 13.170894551255655
# Cut value: 10.223369793285043
# Cut value: 10.39465550472165
# Cut value: 13.170894551255655
# Cut value: 11.220266927750878
# Cut value: 10.953842586460997
# Cut value: 12.981583247162742
# Cut value: 12.670904227455225
# Cut value: 13.18013341254483
# Cut value: 13.18102479217518
# Cut value: 13.18102725263694
# Cut value: 13.18084026549774
# Cut value: 13.18102725263694
# Cut value: 10.08101794861036
# Cut value: 8.532561774361312
# Cut value: 13.18102725263694
# Cut value: 11.54767744347497
# Cut value: 12.64091133600672
# Cut value: 13.182278736683283
# Cut value: 13.182272584062758
# Cut value: 13.182261038745278
# Cut value: 13.182278736683283
# Cut value: 11.580664553999492
# Cut value: 11.805920223099989
# Cut value: 13.182278736683283
# Cut value: 12.298139077922329
# Cut value: 11.500075772643449
# Cut value: 12.921474616841728
# Cut value: 12.892058237713144
# Cut value: 13.17826583672165
# Cut value: 13.182420974308453
# Cut value: 13.182528071115751
# Cut value: 13.182526554441168
# Cut value: 13.182524421362077
# Cut value: 13.182528071115751
# Cut value: 13.165781107917436
# Cut value: 13.107853550679366
# Cut value: 13.182528071115751
# Cut value: 13.168459472470088
# Cut value: 13.182018577297516
# Cut value: 13.183183112423878
# Cut value: 13.183177207875575
# Cut value: 13.183175995513023
# Cut value: 13.145586023964123
# Cut value: 13.183183112423878
# Cut value: 9.858278438228407
# Cut value: 8.37487028193932
# Cut value: 13.183183112423878
# Cut value: 9.976656471817211
# Cut value: 8.803406682509443
# Cut value: 12.429177620681408
# Cut value: 11.944678608537847
# Cut value: 13.169885141613674
# Cut value: 13.183672546708376
# Cut value: 13.18398656227119
# Cut value: 13.183982292692754
# Cut value: 13.18397407202897
# Cut value: 13.18398656227119
# Cut value: 9.78390286137642
# Cut value: 8.47215884688244
# Cut value: 13.18398656227119
# Cut value: 11.663742984227998
# Cut value: 12.482502145829265
# Cut value: 13.184586768164493
# Cut value: 13.18493375342382
# Cut value: 13.184926143459577
# Cut value: 13.184922004404655
# Cut value: 13.18493375342382
# Cut value: 10.198884244810152
# Cut value: 10.34947354520028
# Cut value: 13.18493375342382
# Cut value: 11.17948613575173
# Cut value: 10.785802552743755
# Cut value: 12.903483079079837
# Cut value: 12.651293063057938
# Cut value: 13.184115181276226
# Cut value: 13.186261868087989
# Cut value: 13.186254813506196
# Cut value: 13.186243700570888
# Cut value: 13.186261868087989
# Cut value: 9.973656618301504
# Cut value: 8.467067590493961
# Cut value: 13.186261868087989
# Cut value: 11.60574119935277
# Cut value: 12.588647771823663
# Cut value: 13.186260032523005
# Cut value: 13.18626264095225
# Cut value: 13.186262637430707
# Cut value: 13.186262629781886
# Cut value: 13.18626264095225
# Cut value: 11.629118321348887
# Cut value: 11.874859455711515
# Cut value: 13.18626264095225
# Cut value: 12.357623511804645
# Cut value: 11.622674988663388
# Cut value: 12.932944673496957
# Cut value: 12.924411301889142
# Cut value: 13.182078462905821
# Cut value: 13.186079232253011
# Cut value: 13.186273356687671
# Cut value: 13.186273400815189
# Cut value: 13.186273228801145
# Cut value: 13.186273400815189
# Cut value: 13.159113943525462
# Cut value: 13.12194667620258
# Cut value: 13.186273400815189
# Cut value: 13.176884336103733
# Cut value: 13.182268272568644
# Cut value: 13.186275705135284
# Cut value: 13.186275971531002
# Cut value: 13.186275947959373
# Cut value: 13.186275944089132

# %%
def get_partitions(theta, first_n=1):
    s = Simulator('projectq', circuit.n_qubits)
    s.apply_circuit(circuit, dict(zip(circuit.params_name, theta)))
    state = s.get_qs()
    amp = np.abs(state)**2
    partitions=[]
    for n in range(first_n):
        poi = np.argmax(amp)
        amp[poi] = -1
        bin_string = bin(poi)[2:].zfill(circuit.n_qubits)[::-1]
        partition = [[], []]
        for i, j in enumerate(bin_string):
            partition[int(j)].append(i)
        partitions.append(partition)
    return partitions

def get_cut_value(graph, partitions):
    values = []
    for partition in partitions:
        value = 0
        for p0 in partition[0]:
            for p1 in partition[1]:
                for g in graph:
                    if p0 in g and p1 in g:
                        value += 1
        values.append(value)
    return values

# %%
partitions = get_partitions(res.x, 6)
for i, j in enumerate(partitions):
    print(f'partition {i}: {j}')
# Out:
# partition 0: [[1, 2, 4, 5, 8], [0, 3, 6, 7]]
# partition 1: [[0, 3, 6, 7], [1, 2, 4, 5, 8]]
# partition 2: [[3, 4, 8], [0, 1, 2, 5, 6, 7]]
# partition 3: [[0, 1, 2, 5, 6, 7], [3, 4, 8]]
# partition 4: [[2, 4, 6, 8], [0, 1, 3, 5, 7]]
# partition 5: [[0, 1, 3, 5, 7], [2, 4, 6, 8]]

# %%
cut_values = get_cut_value(g.edges, partitions)
print(f'cut values: {cut_values}')
print(f'\nYour configuration:\ndepth: {depth}\nmethod: {opti}\ntol: {tol}\nstep: {res.nfev}')
# Out:
# cut values: [14, 14, 14, 14, 14, 14]
#
# Your configuration:
# depth: 3
# method: Powell
# tol: 0.001
# step: 267
