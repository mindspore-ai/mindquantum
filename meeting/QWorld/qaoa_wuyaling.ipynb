# %% [markdown]
# # 利用MindQuantum解决组合优化问题

# %%
# !pip install networkx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://repo.huaweicloud.com/repository/pypi/simple
# Looking in links: https://obs-workspace-20180810.obs.cn-north-1.myhuaweicloud.com/pypi/index.html
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (2.6.2)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import networkx as nx

# %%
g = nx.gnm_random_graph(9, 20, seed=42)
nx.draw(g,with_labels=True, font_weight='bold')

# %%
print(list(g.edges))
# Out:
# [(0, 1), (0, 8), (0, 2), (0, 4), (0, 3), (1, 8), (1, 6), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4), (3, 8), (3, 6), (3, 5), (4, 7), (4, 5), (4, 6), (5, 6), (7, 8)]

# %% [markdown]
# ## nx库中的解法

# %%
cut, partition = nx.algorithms.approximation.one_exchange(g)
print(cut, partition)
# Out:
# 14 ({8, 3, 4}, {0, 1, 2, 5, 6, 7})

# %% [markdown]
# ## Try to solve by yourself

# %%
def solution(edges):
    pass

# %%
my_cut = solution(list(g.edges))
print(f'I get {my_cut} cuts')
# Out:
# I get None cuts

# %% [markdown]
# ## QAOA

# %%
from mindquantum import *

# %%
depth = 3
ansatz = MaxCutAnsatz(list(g.edges), depth)

ham = ansatz.hamiltonian
circuit = ansatz.circuit
circuit
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# q0: ──H────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)─────────────────────────────────────────────────────────────ZZ(beta_1)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────ZZ(beta_1)────ZZ(beta_1)────ZZ(beta_1)────ZZ(beta_1)────RX(alpha_1)─────────────────────────────────────────────────────────────ZZ(beta_2)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────ZZ(beta_2)────ZZ(beta_2)────ZZ(beta_2)────ZZ(beta_2)────RX(alpha_2)────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                │             │             │             │             │                                                                                     │                                                                                                                                                │             │             │             │                                                                                     │                                                                                                                                                │             │             │             │
# q1: ──H────ZZ(beta_0)────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)────ZZ(beta_1)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_1)────ZZ(beta_1)────ZZ(beta_1)────ZZ(beta_1)────RX(alpha_1)────ZZ(beta_2)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_2)────ZZ(beta_2)────ZZ(beta_2)────ZZ(beta_2)────RX(alpha_2)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                              │             │             │             │              │             │             │             │                                                                                                                                                                             │             │             │             │              │             │             │             │                                                                                                                                                                             │             │             │             │              │             │             │             │
# q2: ──H──────────────────────┼─────────ZZ(beta_0)────────┼─────────────┼──────────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────ZZ(beta_1)────────┼─────────────┼──────────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_1)────ZZ(beta_1)────RX(alpha_1)────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────ZZ(beta_2)────────┼─────────────┼──────────────┼─────────────┼─────────────┼─────────────┼──────────ZZ(beta_2)────ZZ(beta_2)────RX(alpha_2)──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                              │                           │             │              │             │             │             │              │             │                                                                                                                                                │                           │             │              │             │             │             │              │             │                                                                                                                                                │                           │             │              │             │             │             │              │             │
# q3: ──H──────────────────────┼───────────────────────────┼─────────ZZ(beta_0)─────────┼─────────────┼─────────ZZ(beta_0)────────┼──────────ZZ(beta_0)────────┼──────────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)───────────────────────────────────────────────────────────────────┼───────────────────────────┼─────────ZZ(beta_1)─────────┼─────────────┼─────────ZZ(beta_1)────────┼──────────ZZ(beta_1)────────┼──────────ZZ(beta_1)────ZZ(beta_1)────ZZ(beta_1)────ZZ(beta_1)────RX(alpha_1)───────────────────────────────────────────────────────────────────┼───────────────────────────┼─────────ZZ(beta_2)─────────┼─────────────┼─────────ZZ(beta_2)────────┼──────────ZZ(beta_2)────────┼──────────ZZ(beta_2)────ZZ(beta_2)────ZZ(beta_2)────ZZ(beta_2)────RX(alpha_2)─────────────────────────────────────────────────────────────
#                              │                           │                            │             │                           │                            │              │             │             │             │                                                                                       │                           │                            │             │                           │                            │              │             │             │             │                                                                                       │                           │                            │             │                           │                            │              │             │             │             │
# q4: ──H──────────────────────┼───────────────────────ZZ(beta_0)───────────────────────┼─────────────┼───────────────────────ZZ(beta_0)───────────────────ZZ(beta_0)─────ZZ(beta_0)────────┼─────────────┼─────────────┼──────────ZZ(beta_0)────ZZ(beta_0)─────ZZ(beta_0)────RX(alpha_0)───────────────────────┼───────────────────────ZZ(beta_1)───────────────────────┼─────────────┼───────────────────────ZZ(beta_1)───────────────────ZZ(beta_1)─────ZZ(beta_1)────────┼─────────────┼─────────────┼──────────ZZ(beta_1)────ZZ(beta_1)─────ZZ(beta_1)────RX(alpha_1)───────────────────────┼───────────────────────ZZ(beta_2)───────────────────────┼─────────────┼───────────────────────ZZ(beta_2)───────────────────ZZ(beta_2)─────ZZ(beta_2)────────┼─────────────┼─────────────┼──────────ZZ(beta_2)────ZZ(beta_2)─────ZZ(beta_2)────RX(alpha_2)─────────────────
#                              │                                                        │             │                                                                                     │             │             │              │             │              │                                           │                                                        │             │                                                                                     │             │             │              │             │              │                                           │                                                        │             │                                                                                     │             │             │              │             │              │
# q5: ──H──────────────────────┼────────────────────────────────────────────────────────┼─────────────┼─────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────ZZ(beta_0)─────────┼─────────ZZ(beta_0)─────────┼──────────ZZ(beta_0)────RX(alpha_0)────────┼────────────────────────────────────────────────────────┼─────────────┼─────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────ZZ(beta_1)─────────┼─────────ZZ(beta_1)─────────┼──────────ZZ(beta_1)────RX(alpha_1)────────┼────────────────────────────────────────────────────────┼─────────────┼─────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────ZZ(beta_2)─────────┼─────────ZZ(beta_2)─────────┼──────────ZZ(beta_2)────RX(alpha_2)──
#                              │                                                        │             │                                                                                     │             │                            │                            │              │                            │                                                        │             │                                                                                     │             │                            │                            │              │                            │                                                        │             │                                                                                     │             │                            │                            │              │
# q6: ──H──────────────────────┼────────────────────────────────────────────────────────┼─────────ZZ(beta_0)────────────────────────────────────────────────────────────────────────────────┼─────────ZZ(beta_0)───────────────────────┼────────────────────────ZZ(beta_0)─────ZZ(beta_0)────RX(alpha_0)────────┼────────────────────────────────────────────────────────┼─────────ZZ(beta_1)────────────────────────────────────────────────────────────────────────────────┼─────────ZZ(beta_1)───────────────────────┼────────────────────────ZZ(beta_1)─────ZZ(beta_1)────RX(alpha_1)────────┼────────────────────────────────────────────────────────┼─────────ZZ(beta_2)────────────────────────────────────────────────────────────────────────────────┼─────────ZZ(beta_2)───────────────────────┼────────────────────────ZZ(beta_2)─────ZZ(beta_2)────RX(alpha_2)──
#                              │                                                        │                                                                                                   │                                          │                                                                        │                                                        │                                                                                                   │                                          │                                                                        │                                                        │                                                                                                   │                                          │
# q7: ──H──────────────────────┼────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────ZZ(beta_0)────ZZ(beta_0)────RX(alpha_0)──────────────────────────────────────┼────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────ZZ(beta_1)────ZZ(beta_1)────RX(alpha_1)──────────────────────────────────────┼────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────ZZ(beta_2)────ZZ(beta_2)────RX(alpha_2)────────────────────────────────
#                              │                                                        │                                                                                                   │                                                        │                                                          │                                                        │                                                                                                   │                                                        │                                                          │                                                        │                                                                                                   │                                                        │
# q8: ──H──────────────────ZZ(beta_0)───────────────────────────────────────────────ZZ(beta_0)──────────────────────────────────────────────────────────────────────────────────────────ZZ(beta_0)───────────────────────────────────────────────ZZ(beta_0)────RX(alpha_0)──────────────────────────────────ZZ(beta_1)───────────────────────────────────────────────ZZ(beta_1)──────────────────────────────────────────────────────────────────────────────────────────ZZ(beta_1)───────────────────────────────────────────────ZZ(beta_1)────RX(alpha_1)──────────────────────────────────ZZ(beta_2)───────────────────────────────────────────────ZZ(beta_2)──────────────────────────────────────────────────────────────────────────────────────────ZZ(beta_2)───────────────────────────────────────────────ZZ(beta_2)────RX(alpha_2)────────────────────────────────

# %%
sim = Simulator('projectq', circuit.n_qubits)
grad_ops = sim.get_expectation_with_grad(Hamiltonian(-ham), circuit)

# %%
import numpy as np

grad_ops(np.random.random(size=len(circuit.params_name)))
# Out:
# (array([[-9.40307739-8.55488899e-17j]]),
#  array([[[-1.35339837+0.j,  1.10337184+0.j,  0.72511189+0.j,
#           -0.43161297+0.j,  3.99980871+0.j, -1.0112337 +0.j]]]))

# %% [markdown]
# ### 利用`scipy`的优化器进行优化

# %%
from scipy.optimize import minimize

def fun(x):
    f, g = grad_ops(x)
    print(f"Cut value: {-f.real[0, 0]}")
    return f.real[0, 0], g.real[0, 0]

np.random.seed(1)
x0 = np.random.random(len(circuit.params_name))
optimizers = ['cg', 'COBYLA', 'Powell', 'bfgs']
opti = optimizers[2]
tol = 1e-6
res = minimize(fun, x0, method=opti, jac=True, tol=tol)
# Out:
# Cut value: 7.359574310741286
# Cut value: 8.851406021401965
# Cut value: 10.54669022797708
# Cut value: 9.920566388589535
# Cut value: 10.54669022797708
# Cut value: 9.997158874970722
# Cut value: 10.047673372699943
# Cut value: 9.498720328159084
# Cut value: 10.547076745156337
# Cut value: 10.278467143259395
# Cut value: 10.472854919610374
# Cut value: 10.556530781353139
# Cut value: 10.557337801737937
# Cut value: 10.557338797559808
# Cut value: 10.557331954970884
# Cut value: 10.557338797559808
# Cut value: 6.8121118229667275
# Cut value: 7.276295923208249
# Cut value: 10.557338797559808
# Cut value: 11.243444020769736
# Cut value: 10.007493065167514
# Cut value: 11.397284969976878
# Cut value: 11.397129595974796
# Cut value: 11.397306523185573
# Cut value: 11.397306515305669
# Cut value: 11.397306512610678
# Cut value: 11.397306523185573
# Cut value: 10.815423718769175
# Cut value: 10.418655802666652
# Cut value: 11.397306523185573
# Cut value: 11.243501543519221
# Cut value: 8.98431135548269
# Cut value: 12.016544630010676
# Cut value: 12.013657122239541
# Cut value: 12.07836766736526
# Cut value: 12.014150689765556
# Cut value: 12.081417710973522
# Cut value: 12.081587006369025
# Cut value: 12.08161318316067
# Cut value: 12.081613191862417
# Cut value: 12.081613184126594
# Cut value: 12.081613191862417
# Cut value: 8.569533609974018
# Cut value: 6.525185782374164
# Cut value: 12.081613191862417
# Cut value: 9.789495330637656
# Cut value: 11.531847702230264
# Cut value: 12.096983014861696
# Cut value: 12.09696965256104
# Cut value: 12.096989425857043
# Cut value: 12.096989425850424
# Cut value: 12.096989425557917
# Cut value: 12.096989425857043
# Cut value: 11.979567781027946
# Cut value: 12.073841333438843
# Cut value: 12.096989425857043
# Cut value: 12.235041306465558
# Cut value: 12.143823829412096
# Cut value: 12.241304070458865
# Cut value: 12.237127126707325
# Cut value: 12.242107030386274
# Cut value: 12.242115388083004
# Cut value: 12.242116161283041
# Cut value: 12.242116165699857
# Cut value: 12.242116163671408
# Cut value: 12.242116165699857
# Cut value: 11.01352147164474
# Cut value: 9.660788493113206
# Cut value: 12.242116165699857
# Cut value: 10.674368455391747
# Cut value: 12.368675131747782
# Cut value: 12.421927831680188
# Cut value: 12.422983912745714
# Cut value: 12.422985222046178
# Cut value: 12.422985233673966
# Cut value: 12.422985231833994
# Cut value: 12.422985231821862
# Cut value: 9.534411588729881
# Cut value: 12.422985233673966
# Cut value: 9.113236951748338
# Cut value: 9.081141311340204
# Cut value: 12.422985233673966
# Cut value: 10.106292352246179
# Cut value: 9.651767210112455
# Cut value: 12.00963740838305
# Cut value: 11.851987676524793
# Cut value: 12.42354640327858
# Cut value: 12.423712629154368
# Cut value: 12.423713284789804
# Cut value: 12.423713284886691
# Cut value: 12.423713284881135
# Cut value: 12.423713284877767
# Cut value: 12.423713284886691
# Cut value: 12.028049476228205
# Cut value: 10.305648946569743
# Cut value: 12.423713284886691
# Cut value: 10.229151570461532
# Cut value: 12.993833183681634
# Cut value: 12.934235370982824
# Cut value: 12.99720795649855
# Cut value: 12.997216623176133
# Cut value: 12.997217120021332
# Cut value: 12.997217115636383
# Cut value: 12.997217113059872
# Cut value: 12.997217120021332
# Cut value: 10.323625296746503
# Cut value: 10.864340373808712
# Cut value: 12.997217120021332
# Cut value: 11.61138659803952
# Cut value: 11.640055708428854
# Cut value: 12.964439974826039
# Cut value: 13.023314292688237
# Cut value: 13.023734434668926
# Cut value: 13.02375052938641
# Cut value: 13.023750551214524
# Cut value: 13.023750551167463
# Cut value: 13.023750550741044
# Cut value: 13.023750551214524
# Cut value: 10.515342447962503
# Cut value: 8.61521579764754
# Cut value: 13.023750551214524
# Cut value: 10.824969962697494
# Cut value: 12.879208639323743
# Cut value: 13.117229161195851
# Cut value: 13.117309123028164
# Cut value: 13.117309125656757
# Cut value: 13.11730912304223
# Cut value: 13.117309126388552
# Cut value: 11.664324871447587
# Cut value: 11.782536194595695
# Cut value: 13.117309126388552
# Cut value: 12.188197055454165
# Cut value: 11.55939014684982
# Cut value: 12.856738261068624
# Cut value: 12.876991926881553
# Cut value: 13.114498259089135
# Cut value: 13.117743763615033
# Cut value: 13.117767701074692
# Cut value: 13.117767815557674
# Cut value: 13.117767815925756
# Cut value: 13.117767815922601
# Cut value: 13.11776781591968
# Cut value: 13.117767815925756
# Cut value: 10.109470485008845
# Cut value: 8.585656130275957
# Cut value: 13.117767815925756
# Cut value: 11.351745647932098
# Cut value: 12.654198265725855
# Cut value: 13.130422775947462
# Cut value: 13.131072261507114
# Cut value: 13.131076540737602
# Cut value: 13.131076540923688
# Cut value: 13.131076540789437
# Cut value: 12.917213045394728
# Cut value: 13.131076540923688
# Cut value: 12.917213045394728
# Cut value: 11.457633136349846
# Cut value: 13.131076540923688
# Cut value: 12.814336445583722
# Cut value: 13.156071262408652
# Cut value: 13.161365246030668
# Cut value: 13.161376509811756
# Cut value: 13.161376512614446
# Cut value: 13.161376512604093
# Cut value: 13.161376512020658
# Cut value: 13.161376512614446
# Cut value: 9.850232944813815
# Cut value: 8.273769739790797
# Cut value: 13.161376512614446
# Cut value: 9.972399019930691
# Cut value: 8.88163851160363
# Cut value: 12.404439464849801
# Cut value: 12.036647120970567
# Cut value: 13.149650500645318
# Cut value: 13.161009656039273
# Cut value: 13.161422282072781
# Cut value: 13.161422412224532
# Cut value: 13.161422412460997
# Cut value: 13.161422412460924
# Cut value: 13.161422412460169
# Cut value: 13.161422412460997
# Cut value: 9.569197948536551
# Cut value: 8.246351764382606
# Cut value: 13.161422412460997
# Cut value: 11.628311995899566
# Cut value: 12.393039823367744
# Cut value: 13.164238534199992
# Cut value: 13.164533820714645
# Cut value: 13.164535144504212
# Cut value: 13.16453514448774
# Cut value: 13.164535144458444
# Cut value: 13.164535144504212
# Cut value: 10.229634608062245
# Cut value: 10.355902998389151
# Cut value: 13.164535144504212
# Cut value: 11.196002487574592
# Cut value: 10.910943988163892
# Cut value: 12.98988067951643
# Cut value: 12.835666958699875
# Cut value: 13.17798288975932
# Cut value: 13.178634126701597
# Cut value: 13.178674791782981
# Cut value: 13.17867496285728
# Cut value: 13.178674963332824
# Cut value: 13.178674963202033
# Cut value: 13.178674963332824
# Cut value: 10.04084124088429
# Cut value: 8.533016815891795
# Cut value: 13.178674963332824
# Cut value: 11.616049598830084
# Cut value: 12.607475759220854
# Cut value: 13.178753377498342
# Cut value: 13.178755871076104
# Cut value: 13.178755904650455
# Cut value: 13.178755904650078
# Cut value: 13.178755904649222
# Cut value: 13.178755904650455
# Cut value: 11.564962535873718
# Cut value: 11.77803783273436
# Cut value: 13.178755904650455
# Cut value: 12.277059555908036
# Cut value: 11.424801392298807
# Cut value: 12.924889074625847
# Cut value: 12.859512568000646
# Cut value: 13.17583542422192
# Cut value: 13.180060033700364
# Cut value: 13.180087813795929
# Cut value: 13.180088100803754
# Cut value: 13.180088101943365
# Cut value: 13.180088101934235
# Cut value: 13.18008810192629
# Cut value: 13.180088101943365
# Cut value: 13.152576747919296
# Cut value: 13.075052229383168
# Cut value: 13.180088101943365
# Cut value: 13.16105425600822
# Cut value: 13.178421053176743
# Cut value: 13.180699565291729
# Cut value: 13.180699703496149
# Cut value: 13.180699717924796
# Cut value: 13.180699717924664
# Cut value: 13.180699717912653
# Cut value: 13.118415480867341
# Cut value: 13.180699717924796
# Cut value: 9.854672522832558
# Cut value: 8.373207367300324
# Cut value: 13.180699717924796
# Cut value: 9.980485410286434
# Cut value: 8.810288227197148
# Cut value: 12.448390376874956
# Cut value: 11.901075555928601
# Cut value: 13.169349838306658
# Cut value: 13.182656119489756
# Cut value: 13.182824004347083
# Cut value: 13.182824786713066
# Cut value: 13.18282479194978
# Cut value: 13.18282479194204
# Cut value: 13.182824791915532
# Cut value: 13.18282479194978
# Cut value: 9.757348821753038
# Cut value: 8.46199687524065
# Cut value: 13.18282479194978
# Cut value: 11.681578775434351
# Cut value: 12.464775787816766
# Cut value: 13.184196475654325
# Cut value: 13.184516309611002
# Cut value: 13.184516745903586
# Cut value: 13.184516745891717
# Cut value: 13.184516745881584
# Cut value: 13.184516745903586
# Cut value: 10.197492412635409
# Cut value: 10.344810066478349
# Cut value: 13.184516745903586
# Cut value: 11.177347014944857
# Cut value: 10.782645333828683
# Cut value: 12.905121798743291
# Cut value: 12.648719807258681
# Cut value: 13.18387470821407
# Cut value: 13.185993669012152
# Cut value: 13.185993897982973
# Cut value: 13.185993951598514
# Cut value: 13.18599395159498
# Cut value: 13.185993951572787
# Cut value: 13.185993951598514
# Cut value: 9.9604385502721
# Cut value: 8.462256981033452
# Cut value: 13.185993951598514
# Cut value: 11.613351860220785
# Cut value: 12.581928507291227
# Cut value: 13.186000108758762
# Cut value: 13.186002472072255
# Cut value: 13.186002490102062
# Cut value: 13.186002490102013
# Cut value: 13.186002490101927
# Cut value: 13.186002490102062
# Cut value: 11.62441397641144
# Cut value: 11.868294161333935
# Cut value: 13.186002490102062
# Cut value: 12.351136297327555
# Cut value: 11.612397966843247
# Cut value: 12.931964745534815
# Cut value: 12.922693073284005
# Cut value: 13.181798485827905
# Cut value: 13.185820921863616
# Cut value: 13.186014342566763
# Cut value: 13.186014400487629
# Cut value: 13.186014400570166
# Cut value: 13.186014400570167
# Cut value: 13.186014400569942
# Cut value: 13.186014400570167
# Cut value: 13.144377869739156
# Cut value: 13.091054236010876
# Cut value: 13.186014400570167
# Cut value: 13.172082256474308
# Cut value: 13.179974096881562
# Cut value: 13.186016900914105
# Cut value: 13.186018045901083
# Cut value: 13.186018045965291
# Cut value: 13.186018045965334
# Cut value: 13.186018045965351
# Cut value: 13.18601804595524
# Cut value: 13.186018045965163
# Cut value: 13.186390492813645
# Cut value: 13.186018045965351
# Cut value: 9.859640374159556
# Cut value: 8.403145134075249
# Cut value: 13.186018045965351
# Cut value: 9.972111081029944
# Cut value: 8.804415114442996
# Cut value: 12.425769747425171
# Cut value: 11.952977703654078
# Cut value: 13.172216143072227
# Cut value: 13.18620741680133
# Cut value: 13.186563569654872
# Cut value: 13.186564009628519
# Cut value: 13.186564012737694
# Cut value: 13.186564012739622
# Cut value: 13.18656401273071
# Cut value: 13.186564012739622
# Cut value: 9.86783610746295
# Cut value: 8.542214763888722
# Cut value: 13.186564012739622
# Cut value: 11.650237324843847
# Cut value: 12.521440069905044
# Cut value: 13.186331865885975
# Cut value: 13.18672198910921
# Cut value: 13.186722022901275
# Cut value: 13.186722022899842
# Cut value: 13.186722022899529
# Cut value: 13.186722022901275
# Cut value: 10.192686902803647
# Cut value: 10.364087772811367
# Cut value: 13.186722022901275
# Cut value: 11.184047537277486
# Cut value: 10.791774186099072
# Cut value: 12.883753182913217
# Cut value: 12.68755300683123
# Cut value: 13.184442100422508
# Cut value: 13.186858680434351
# Cut value: 13.186874680307238
# Cut value: 13.186874690715804
# Cut value: 13.186874690754845
# Cut value: 13.186874690753445
# Cut value: 13.186874690753228
# Cut value: 13.186874690754845
# Cut value: 9.967687927711747
# Cut value: 8.466584359549259
# Cut value: 13.186874690754845
# Cut value: 11.612644492137452
# Cut value: 12.583473322911207
# Cut value: 13.186878242481097
# Cut value: 13.186880899301556
# Cut value: 13.186880916260915
# Cut value: 13.186880916260893
# Cut value: 13.186880916260831
# Cut value: 13.186880916260915
# Cut value: 11.649837442074306
# Cut value: 11.89865380223005
# Cut value: 13.186880916260915
# Cut value: 12.376810355095436
# Cut value: 11.667628763087913
# Cut value: 12.935421086757444
# Cut value: 12.935621131606526
# Cut value: 13.182766064948154
# Cut value: 13.186864473541313
# Cut value: 13.186885068337208
# Cut value: 13.186885078075257
# Cut value: 13.18688507807867
# Cut value: 13.186885078078603
# Cut value: 13.186885078078584
# Cut value: 13.18688507807867
# Cut value: 13.143110614209881
# Cut value: 13.09045665890656
# Cut value: 13.18688507807867
# Cut value: 13.172962982612681
# Cut value: 13.18037957322685
# Cut value: 13.18689726443199
# Cut value: 13.186898625432619
# Cut value: 13.186898626111255
# Cut value: 13.186898626111624
# Cut value: 13.186898626111383
# Cut value: 13.186908892571342
# Cut value: 13.186898626111624
# Cut value: 13.186908892571342
# Cut value: 13.185070418095492
# Cut value: 13.186908892571342
# Cut value: 13.186477986186922
# Cut value: 13.18700801613827
# Cut value: 13.18701292517897
# Cut value: 13.187012925330905
# Cut value: 13.18701292533181
# Cut value: 13.187012925330396
# Cut value: 13.18701292533181
# Cut value: 13.144148238835916
# Cut value: 13.087064389811703
# Cut value: 13.18701292533181
# Cut value: 13.172004478774081
# Cut value: 13.180992328051314
# Cut value: 13.187011572091809
# Cut value: 13.187012925221808
# Cut value: 13.187012925363584
# Cut value: 13.187012925363593
# Cut value: 13.187012925342923
# Cut value: 13.187012925361671
# Cut value: 13.18701292536328
# Cut value: 13.187012925363522
# Cut value: 13.187012925363563
# Cut value: 13.187012925363579
# Cut value: 13.187012925363614
# Cut value: 13.187012925363591
# Cut value: 13.1870129253636
# Cut value: 13.187012925363529
# Cut value: 13.187012925363565
# Cut value: 13.187012925363618
# Cut value: 13.187012925363558
# Cut value: 13.187012925363579
# Cut value: 13.18701292536356
# Cut value: 13.187012925363618
# Cut value: 9.924538028947026
# Cut value: 8.587093685405108
# Cut value: 13.187012925363618
# Cut value: 11.63698398950466
# Cut value: 12.547993609435233
# Cut value: 13.18659159179306
# Cut value: 13.187013735635912
# Cut value: 13.18701401073459
# Cut value: 13.187014010734547
# Cut value: 13.187014010734554
# Cut value: 13.18701401073459
# Cut value: 10.191237679772108
# Cut value: 10.38209480581958
# Cut value: 13.18701401073459
# Cut value: 11.191516589577171
# Cut value: 10.824921544697927
# Cut value: 12.877993084189786
# Cut value: 12.712216270616441
# Cut value: 13.184559278979236
# Cut value: 13.186982444665773
# Cut value: 13.18701621732513
# Cut value: 13.18701621823648
# Cut value: 13.1870162182378
# Cut value: 13.187016218237801
# Cut value: 13.187016218237735
# Cut value: 13.187016218237801
# Cut value: 9.98451979575341
# Cut value: 8.479570559708694
# Cut value: 13.187016218237801
# Cut value: 11.612942843597587
# Cut value: 12.58832549965649
# Cut value: 13.187013606507808
# Cut value: 13.18701673468544
# Cut value: 13.187016741052638
# Cut value: 13.187016741052634
# Cut value: 13.18701674105263
# Cut value: 13.187016741052638
# Cut value: 11.663891455102041
# Cut value: 11.911569089277913
# Cut value: 13.187016741052638
# Cut value: 12.387929362549084
# Cut value: 11.687881847573745
# Cut value: 12.937891862298372
# Cut value: 12.9375589735209
# Cut value: 13.182981620549398
# Cut value: 13.186795126697199
# Cut value: 13.187018438376978
# Cut value: 13.187018477397313
# Cut value: 13.187018477419027
# Cut value: 13.187018477419022
# Cut value: 13.187018477419006
# Cut value: 13.187018477419027
# Cut value: 13.186913405284752
# Cut value: 13.186704263926954
# Cut value: 13.187018477419027
# Cut value: 13.186968997500902
# Cut value: 13.187005378374879
# Cut value: 13.187018670976006
# Cut value: 13.18701867097712
# Cut value: 13.187018670977015
# Cut value: 13.187018670976997
# Cut value: 13.187018670977114
# Cut value: 13.187018670977036

# %%
def get_partitions(theta, first_n=1):
    s = Simulator('projectq', circuit.n_qubits)
    s.apply_circuit(circuit, dict(zip(circuit.params_name, theta)))
    state = s.get_qs()
    amp = np.abs(state)**2
    partitions=[]
    for n in range(first_n):
        poi = np.argmax(amp)
        amp[poi] = -1
        bin_string = bin(poi)[2:].zfill(circuit.n_qubits)[::-1]
        partition = [[], []]
        for i, j in enumerate(bin_string):
            partition[int(j)].append(i)
        partitions.append(partition)
    return partitions

def get_cut_value(graph, partitions):
    values = []
    for partition in partitions:
        value = 0
        for p0 in partition[0]:
            for p1 in partition[1]:
                for g in graph:
                    if p0 in g and p1 in g:
                        value += 1
        values.append(value)
    return values

# %%
partitions = get_partitions(res.x, 6)
for i, j in enumerate(partitions):
    print(f'partition {i}: {j}')
# Out:
# partition 0: [[1, 2, 4, 5, 8], [0, 3, 6, 7]]
# partition 1: [[0, 3, 6, 7], [1, 2, 4, 5, 8]]
# partition 2: [[0, 1, 2, 5, 6, 7], [3, 4, 8]]
# partition 3: [[3, 4, 8], [0, 1, 2, 5, 6, 7]]
# partition 4: [[0, 1, 3, 5, 7], [2, 4, 6, 8]]
# partition 5: [[2, 4, 6, 8], [0, 1, 3, 5, 7]]

# %%
cut_values = get_cut_value(g.edges, partitions)
print(f'cut values: {cut_values}')
print(f'\nYour configuration:\ndepth: {depth}\nmethod: {opti}\ntol: {tol}\nstep: {res.nfev}')
# Out:
# cut values: [14, 14, 14, 14, 14, 14]
#
# Your configuration:
# depth: 3
# method: Powell
# tol: 1e-06
# step: 503
