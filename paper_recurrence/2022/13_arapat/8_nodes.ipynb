# %% [markdown]
# # 8 节点最大割问题求解
# ## 主程序 0：先画出8 节点的图，每个节点有 3 条边。并采用经典穷举法，计算其最大切割边数。

# %%
import networkx as nx
# python.dataScience.textOutputLimit = 0

g_8 = nx.Graph()
nx.add_path(g_8, [0, 1])
nx.add_path(g_8, [1, 2])
nx.add_path(g_8, [2, 3])
nx.add_path(g_8, [3, 4])
nx.add_path(g_8, [4, 5])
nx.add_path(g_8, [5, 6])
nx.add_path(g_8, [6, 7])
nx.add_path(g_8, [7, 0])
nx.add_path(g_8, [0, 4])
nx.add_path(g_8, [1, 5])
nx.add_path(g_8, [2, 6])
nx.add_path(g_8, [3, 7])
nx.draw(g_8, with_labels=True, font_weight='bold') # 画出图

for i in g_8.nodes:
    print('one size:', [i], 'cut=', nx.cut_size(g_8, [i]))            # 一组 1 个节点、另一组 7 个节点的所有情况
    for j in range(i):
        print('one size:', [i, j], 'cut=', nx.cut_size(g_8, [i, j]))  # 一组 2 个节点、另一组 6 个节点的所有情况
        for k in range(j):
            print('one size:', [i, j, k], 'cut=', nx.cut_size(g_8, [i, j, k]))  # 一组 3 个节点、另一组 5 个节点的所有情况
            for m in range(k):
                print('one size:', [i, j, k, m], 'cut=', nx.cut_size(g_8, [i, j, k, m]))  # 一组 4 个节点、另一组 4 个节点的所有情况
# Out:
# one size: [0] cut= 3
# one size: [1] cut= 3
# one size: [1, 0] cut= 4
# one size: [2] cut= 3
# one size: [2, 0] cut= 6
# one size: [2, 1] cut= 4
# one size: [2, 1, 0] cut= 5
# one size: [3] cut= 3
# one size: [3, 0] cut= 6
# one size: [3, 1] cut= 6
# one size: [3, 1, 0] cut= 7
# one size: [3, 2] cut= 4
# one size: [3, 2, 0] cut= 7
# one size: [3, 2, 1] cut= 5
# one size: [3, 2, 1, 0] cut= 6
# one size: [4] cut= 3
# one size: [4, 0] cut= 4
# one size: [4, 1] cut= 6
# one size: [4, 1, 0] cut= 5
# one size: [4, 2] cut= 6
# one size: [4, 2, 0] cut= 7
# one size: [4, 2, 1] cut= 7
# one size: [4, 2, 1, 0] cut= 6
# one size: [4, 3] cut= 4
# one size: [4, 3, 0] cut= 5
# one size: [4, 3, 1] cut= 7
# one size: [4, 3, 1, 0] cut= 6
# one size: [4, 3, 2] cut= 5
# one size: [4, 3, 2, 0] cut= 6
# one size: [4, 3, 2, 1] cut= 6
# one size: [5] cut= 3
# one size: [5, 0] cut= 6
# one size: [5, 1] cut= 4
# one size: [5, 1, 0] cut= 5
# one size: [5, 2] cut= 6
# one size: [5, 2, 0] cut= 9
# one size: [5, 2, 1] cut= 5
# one size: [5, 2, 1, 0] cut= 6
# one size: [5, 3] cut= 6
# one size: [5, 3, 0] cut= 9
# one size: [5, 3, 1] cut= 7
# one size: [5, 3, 1, 0] cut= 8
# one size: [5, 3, 2] cut= 7
# one size: [5, 3, 2, 0] cut= 10
# one size: [5, 3, 2, 1] cut= 6
# one size: [5, 4] cut= 4
# one size: [5, 4, 0] cut= 5
# one size: [5, 4, 1] cut= 5
# one size: [5, 4, 1, 0] cut= 4
# one size: [5, 4, 2] cut= 7
# one size: [5, 4, 2, 0] cut= 8
# one size: [5, 4, 2, 1] cut= 6
# one size: [5, 4, 3] cut= 5
# one size: [5, 4, 3, 0] cut= 6
# one size: [5, 4, 3, 1] cut= 6
# one size: [5, 4, 3, 2] cut= 6
# one size: [6] cut= 3
# one size: [6, 0] cut= 6
# one size: [6, 1] cut= 6
# one size: [6, 1, 0] cut= 7
# one size: [6, 2] cut= 4
# one size: [6, 2, 0] cut= 7
# one size: [6, 2, 1] cut= 5
# one size: [6, 2, 1, 0] cut= 6
# one size: [6, 3] cut= 6
# one size: [6, 3, 0] cut= 9
# one size: [6, 3, 1] cut= 9
# one size: [6, 3, 1, 0] cut= 10
# one size: [6, 3, 2] cut= 5
# one size: [6, 3, 2, 0] cut= 8
# one size: [6, 3, 2, 1] cut= 6
# one size: [6, 4] cut= 6
# one size: [6, 4, 0] cut= 7
# one size: [6, 4, 1] cut= 9
# one size: [6, 4, 1, 0] cut= 8
# one size: [6, 4, 2] cut= 7
# one size: [6, 4, 2, 0] cut= 8
# one size: [6, 4, 2, 1] cut= 8
# one size: [6, 4, 3] cut= 7
# one size: [6, 4, 3, 0] cut= 8
# one size: [6, 4, 3, 1] cut= 10
# one size: [6, 4, 3, 2] cut= 6
# one size: [6, 5] cut= 4
# one size: [6, 5, 0] cut= 7
# one size: [6, 5, 1] cut= 5
# one size: [6, 5, 1, 0] cut= 6
# one size: [6, 5, 2] cut= 5
# one size: [6, 5, 2, 0] cut= 8
# one size: [6, 5, 2, 1] cut= 4
# one size: [6, 5, 3] cut= 7
# one size: [6, 5, 3, 0] cut= 10
# one size: [6, 5, 3, 1] cut= 8
# one size: [6, 5, 3, 2] cut= 6
# one size: [6, 5, 4] cut= 5
# one size: [6, 5, 4, 0] cut= 6
# one size: [6, 5, 4, 1] cut= 6
# one size: [6, 5, 4, 2] cut= 6
# one size: [6, 5, 4, 3] cut= 6
# one size: [7] cut= 3
# one size: [7, 0] cut= 4
# one size: [7, 1] cut= 6
# one size: [7, 1, 0] cut= 5
# one size: [7, 2] cut= 6
# one size: [7, 2, 0] cut= 7
# one size: [7, 2, 1] cut= 7
# one size: [7, 2, 1, 0] cut= 6
# one size: [7, 3] cut= 4
# one size: [7, 3, 0] cut= 5
# one size: [7, 3, 1] cut= 7
# one size: [7, 3, 1, 0] cut= 6
# one size: [7, 3, 2] cut= 5
# one size: [7, 3, 2, 0] cut= 6
# one size: [7, 3, 2, 1] cut= 6
# one size: [7, 4] cut= 6
# one size: [7, 4, 0] cut= 5
# one size: [7, 4, 1] cut= 9
# one size: [7, 4, 1, 0] cut= 6
# one size: [7, 4, 2] cut= 9
# one size: [7, 4, 2, 0] cut= 8
# one size: [7, 4, 2, 1] cut= 10
# one size: [7, 4, 3] cut= 5
# one size: [7, 4, 3, 0] cut= 4
# one size: [7, 4, 3, 1] cut= 8
# one size: [7, 4, 3, 2] cut= 6
# one size: [7, 5] cut= 6
# one size: [7, 5, 0] cut= 7
# one size: [7, 5, 1] cut= 7
# one size: [7, 5, 1, 0] cut= 6
# one size: [7, 5, 2] cut= 9
# one size: [7, 5, 2, 0] cut= 10
# one size: [7, 5, 2, 1] cut= 8
# one size: [7, 5, 3] cut= 7
# one size: [7, 5, 3, 0] cut= 8
# one size: [7, 5, 3, 1] cut= 8
# one size: [7, 5, 3, 2] cut= 8
# one size: [7, 5, 4] cut= 7
# one size: [7, 5, 4, 0] cut= 6
# one size: [7, 5, 4, 1] cut= 8
# one size: [7, 5, 4, 2] cut= 10
# one size: [7, 5, 4, 3] cut= 6
# one size: [7, 6] cut= 4
# one size: [7, 6, 0] cut= 5
# one size: [7, 6, 1] cut= 7
# one size: [7, 6, 1, 0] cut= 6
# one size: [7, 6, 2] cut= 5
# one size: [7, 6, 2, 0] cut= 6
# one size: [7, 6, 2, 1] cut= 6
# one size: [7, 6, 3] cut= 5
# one size: [7, 6, 3, 0] cut= 6
# one size: [7, 6, 3, 1] cut= 8
# one size: [7, 6, 3, 2] cut= 4
# one size: [7, 6, 4] cut= 7
# one size: [7, 6, 4, 0] cut= 6
# one size: [7, 6, 4, 1] cut= 10
# one size: [7, 6, 4, 2] cut= 8
# one size: [7, 6, 4, 3] cut= 6
# one size: [7, 6, 5] cut= 5
# one size: [7, 6, 5, 0] cut= 6
# one size: [7, 6, 5, 1] cut= 6
# one size: [7, 6, 5, 2] cut= 6
# one size: [7, 6, 5, 3] cut= 6
# one size: [7, 6, 5, 4] cut= 6

# %% [markdown]
# 从上面结果可以看出，穷举法得到的最大割边数为 10。如果对节点分组的左右进行区分，则一共有 8 种分组方法可以使切割边数最大，即该问题有 8 个简并解，分别为： \[5, 3, 2, 0 | 7, 6, 4, 1\] 、\[7, 6, 4, 1 | 5, 3, 2, 0 \]、\[6, 3, 1, 0 | 7, 5, 4, 2\]、\[7, 5, 4, 2 | 6, 3, 1, 0\]、\[6, 4, 3, 1 | 7, 5, 2, 0\]、\[7, 5, 2, 0 | 6, 4, 3, 1\]、\[6, 5, 3, 0 | 7, 4, 2, 1\] 和 \[7, 4, 2, 1 | 6, 5, 3, 0\]。

# %%
import numpy as np
import mindspore as ms
from mindquantum import *
import matplotlib.pyplot as plt
from mindspore import context, nn, Parameter, Tensor
from mindspore.common.initializer import initializer
context.set_context(mode=context.PYNATIVE_MODE)
np.random.seed(1)
ms.set_seed(1)

# 构建量子线路
def build_hc(g, para): # 对图中的每条边作用 ZZ 门
    hc = Circuit()                 
    for i in g.edges:
        hc += ZZ(para).on(i)                     
    return hc

def build_hb(g, para): # 对图中的每个节点作用 RX 门
    hb = Circuit()                
    for i in g.nodes:
        hb += RX(para).on(i)      
    return hb
    
def build_ansatz(g, num_layer):   # g 是 max-cut 问题的图，num_layer 是 ansatz 线路的层数
    circ = Circuit()                  
    for i in range(num_layer):
        circ += build_hc(g, f'g{i}')       # 添加 Uc 对应的线路，参数记为 g0、g1、g2...
        circ += build_hb(g, f'b{i}')       # 添加 Ub 对应的线路，参数记为 b0、b1、b2...
    return circ

def build_ham(g):
    ham = QubitOperator()
    for i in g.edges:
        ham += QubitOperator(f'Z{i[0]} Z{i[1]}')  # 生成哈密顿量 Hc
    return ham

num_layer = 7
ham = Hamiltonian(build_ham(g_8))      # 生成哈密顿量
init_state_circ = UN(H, g_8.nodes)         # 生成均匀叠加态，即对所有量子比特作用H门
ansatz = build_ansatz(g_8, num_layer)   # 生成拟设线路
circ = init_state_circ + ansatz                  # 将初始化线路与拟设线路组合成总的线路

sim = Simulator('projectq', circ.n_qubits) # 创建模拟器
grad_ops = sim.get_expectation_with_grad(ham, 
                                                                        circ, 
                                                                        encoder_params_name=circ.params_name)

# 采用一个 LSTM 作为对量子线路参数的经典优化器 
# LSTM 输入为量子线路旧的参数，输出作为量子线路新的参数。
class TrainableLSTM(nn.Cell): 
    def __init__(self):
        super(TrainableLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=len(circ.params_name),
                                            hidden_size=len(circ.params_name),
                                            num_layers=1,
                                            has_bias=True,
                                            batch_first=False,
                                            bidirectional=False)
        self.hidden_size = self.lstm.hidden_size
        self.batch_size = 1
        self.num_layers = 1
        self.hx = (Parameter(initializer( 'normal', shape=[self.num_layers, self.batch_size, self.hidden_size], dtype=ms.float32), name='h'),
                         Parameter(initializer('normal', shape=[self.num_layers, self.batch_size, self.hidden_size], dtype=ms.float32), name='c'))

    def construct(self, x):
        _, (x, _) = self.lstm(x, self.hx)
        return x

# LSTM 层的损失函数为量子线路最终的期望值。
class All_Net(nn.Cell):
    def __init__(self, grad_ops, init_paras):
        super(All_Net, self).__init__()
        self.lstm = TrainableLSTM()
        self.qnn_ops = MQEncoderOnlyOps(grad_ops) # 量子线路的参数不直接参与训练
        self.init_paras = init_paras
        self.squeeze = ms.ops.Squeeze(0)

    def construct(self):  # x 为量子线路旧的网络参数， out 为量子线路新的参数
        self.init_paras = self.lstm(self.init_paras)
        x = self.squeeze(self.init_paras)
        out = self.qnn_ops(x)
        return out

paras = Tensor(np.random.random([1, 1, len(circ.params_name)]).astype(np.float32))  # 量子线路初始参数
all_net = All_Net(grad_ops, paras)
opt = nn.Adam(all_net.trainable_params(),  learning_rate=0.1)  # 对 LSTM 层的参数，采用 Adam 进行优化
train_net = nn.TrainOneStepCell(all_net, opt)
train_net.set_train()

# 获取训练过程数据
cut_data = []
steps = 500
for step in range(steps):
    cut = (len(g_8.edges) - train_net()) / 2      # 将神经网络训练一步并计算得到的结果（切割边数）。注意：每当'train_net()'运行一次，神经网络就训练了一步
    cut_data.append(cut.asnumpy()[0,0])
    if step %10 == 0:
        print("train step:", step, ", cut:", cut[0,0])  # 每训练10步，打印当前训练步数和当前得到的切割边数

sim.reset()
sim.apply_circuit(circ, pr=all_net.init_paras[0,0].asnumpy())
result = sim.get_expectation(ham).real 
print('\n采用最终参数下，预期切割边数：',  (len(g_8.edges) - result) / 2)

plt.figure()
plt.plot(cut_data, label = '8_nodes_cut', linestyle='-', marker='o', color='b') # 画出训练过程中，切割边数的变化情况
plt.title('MaxCut QAOA', fontsize=12)
plt.legend() 
plt.xlabel('Steps ', fontsize=10)
plt.ylabel('Max_Cut_number', fontsize=10)
plt.savefig('./src/8_nodes.png')
plt.show()

# 我们将最优参数代入量子线路，通过对量子线路进行1000次采样，画出最终量子态在计算基矢下的概率分布：
sim.reset()
pr = dict(zip(ansatz.params_name, all_net.init_paras[0,0].asnumpy()))
circ.measure_all()                                      # 为线路中所有比特添加测量门
sim.sampling(circ, pr=pr, shots=1000)      # 运行线路1000次并打印结果
# Out:
# [WARNING] DEBUG(12482,7f6361960740,python):2022-06-28-07:26:13.915.761 [mindspore/ccsrc/debug/debugger/debugger.cc:95] Debugger] Not enabling debugger. Debugger does not support CPU.
# train step: 0 , cut: 6.1873155
# train step: 10 , cut: 9.140121
# train step: 20 , cut: 9.266391
# train step: 30 , cut: 9.463311
# train step: 40 , cut: 9.5336
# train step: 50 , cut: 9.662776
# train step: 60 , cut: 9.690742
# train step: 70 , cut: 9.702236
# train step: 80 , cut: 9.712858
# train step: 90 , cut: 9.714352
# train step: 100 , cut: 9.715347
# train step: 110 , cut: 9.716146
# train step: 120 , cut: 9.716878
# train step: 130 , cut: 9.717632
# train step: 140 , cut: 9.718614
# train step: 150 , cut: 9.719915
# train step: 160 , cut: 9.721366
# train step: 170 , cut: 9.722631
# train step: 180 , cut: 9.723632
# train step: 190 , cut: 9.724326
# train step: 200 , cut: 9.724739
# train step: 210 , cut: 9.72505
# train step: 220 , cut: 9.72548
# train step: 230 , cut: 9.726929
# train step: 240 , cut: 9.753406
# train step: 250 , cut: 9.826163
# train step: 260 , cut: 9.863395
# train step: 270 , cut: 9.874019
# train step: 280 , cut: 9.874605
# train step: 290 , cut: 9.874498
# train step: 300 , cut: 9.876144
# train step: 310 , cut: 9.877056
# train step: 320 , cut: 9.877674
# train step: 330 , cut: 9.878366
# train step: 340 , cut: 9.879087
# train step: 350 , cut: 9.879819
# train step: 360 , cut: 9.880503
# train step: 370 , cut: 9.881123
# train step: 380 , cut: 9.881688
# train step: 390 , cut: 9.882186
# train step: 400 , cut: 9.882611
# train step: 410 , cut: 9.882971
# train step: 420 , cut: 9.883274
# train step: 430 , cut: 9.883528
# train step: 440 , cut: 9.883739
# train step: 450 , cut: 9.883917
# train step: 460 , cut: 9.884066
# train step: 470 , cut: 9.884192
# train step: 480 , cut: 9.8843
# train step: 490 , cut: 9.884393
#
# 采用最终参数下，预期切割边数： 9.884465217897535
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# shots: 1000
# Keys: q7 q6 q5 q4 q3 q2 q1 q0│0.00   0.037       0.074       0.111       0.148       0.185
# ─────────────────────────────┼───────────┴───────────┴───────────┴───────────┴───────────┴
#                      00000111│▒
#                              │
#                      00010001│▒
#                              │
#                      00011100│▒
#                              │
#                      00100101│▒
#                              │
#                      00101101│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#                              │
#                      00110101│▒
#                              │
#                      01001001│▒
#                              │
#                      01001010│▒
#                              │
#                      01001011│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#                              │
#                      01010010│▒
#                              │
#                      01010101│▒▒▒
#                              │
#                      01011001│▒
#                              │
#                      01011010│▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓
#                              │
#                      01101000│▒
#                              │
#                      01101001│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#                              │
#                      01101011│▒
#                              │
#                      01110110│▒
#                              │
#                      01111000│▒
#                              │
#                      01111010│▒
#                              │
#                      10000111│▒
#                              │
#                      10010010│▒
#                              │
#                      10010100│▒
#                              │
#                      10010110│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#                              │
#                      10011010│▒
#                              │
#                      10100101│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#                              │
#                      10101001│▒
#                              │
#                      10101010│▒▒▒
#                              │
#                      10101100│▒
#                              │
#                      10101101│▒
#                              │
#                      10110100│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#                              │
#                      11000111│▒
#                              │
#                      11001010│▒
#                              │
#                      11010010│▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#                              │
#                      11010100│▒
#                              │
#                      11010110│▒
#                              │
#                      11101100│▒
#                              │
#                      11110000│▒
#                              │
# {'00000111': 1, '00010001': 1, '00011100': 1, '00100101': 2, '00101101': 133, '00110101': 1, '01001001': 2, '01001010': 1, '01001011': 102, '01010010': 1, '01010101': 9, '01011001': 1, '01011010': 148, '01101000': 1, '01101001': 110, '01101011': 1, '01110110': 1, '01111000': 1, '01111010': 1, '10000111': 1, '10010010': 1, '10010100': 1, '10010110': 118, '10011010': 2, '10100101': 124, '10101001': 2, '10101010': 7, '10101100': 1, '10101101': 1, '10110100': 98, '11000111': 1, '11001010': 2, '11010010': 118, '11010100': 2, '11010110': 1, '11101100': 1, '11110000': 1}

# %% [markdown]
# 根据概率分布图我们发现，该 8 节点的 Max-Cut 问题具有 8 个简并解，每个解对应的概率大概为 12.5%。
#
# `00101101`：编号 1、4、6、7 的节点在左边，编号 0、2、3、5 的节点在右边。
#
# `01001011`：编号 2、4、5、7 的节点在左边，编号 0、1、3、6 的节点在右边。
#
# `01011010`：编号 0、2、5、7 的节点在左边，编号 1、3、4、6 的节点在右边。
#
# `01101001`：编号 1、2、4、7 的节点在左边，编号 0、3、5、6 的节点在右边。
#
# `10010110`：编号 0、3、5、6 的节点在左边，编号 1、2、4、7 的节点在右边。
#
# `10100101`：编号 1、3、4、6 的节点在左边，编号 0、2、5、7  的节点在右边。
#
# `10110100`：编号 0、1、3、6 的节点在左边，编号 2、4、5、7 的节点在右边。
#
# `11010010`：编号 0、2、3、5 的节点在左边，编号 1、4、6、7  的节点在右边。
#
# 此结果和经典穷举法结果一致。
