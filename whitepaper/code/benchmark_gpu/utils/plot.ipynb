# %%
import os
from read_data import *

data_path = os.path.abspath('../src/.benchmarks/Linux-CPython-3.9-64bit')
data_files = []
for i in os.listdir(data_path):
    data_files.append(os.path.join(data_path, i))
data = ext_info(data_files)
# Out:
# Hit same task configuration: ['qiskit_gpu', 'simple_circuit', 4]. Strategy: override
# Hit same task configuration: ['qiskit_gpu', 'simple_circuit', 5]. Strategy: override
# Hit same task configuration: ['qiskit_gpu', 'simple_circuit', 6]. Strategy: override
# Hit same task configuration: ['qiskit_gpu', 'simple_circuit', 7]. Strategy: override
# Hit same task configuration: ['qiskit_gpu', 'simple_circuit', 8]. Strategy: override
# Hit same task configuration: ['qiskit_gpu', 'simple_circuit', 4]. Strategy: override
# Hit same task configuration: ['qiskit_gpu', 'simple_circuit', 5]. Strategy: override
# Hit same task configuration: ['qiskit_gpu', 'simple_circuit', 6]. Strategy: override
# Hit same task configuration: ['qiskit_gpu', 'simple_circuit', 7]. Strategy: override
# Hit same task configuration: ['qiskit_gpu', 'simple_circuit', 8]. Strategy: override
# Hit same task configuration: ['qiskit_gpu', 'simple_circuit', 9]. Strategy: override
# ...

# %%
import matplotlib.pyplot as plt
show_task('simple_circuit', data, True)
